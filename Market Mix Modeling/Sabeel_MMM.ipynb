# %% [markdown]
# ### <b> Title:</b> Performing Market Mix Modeling on an advertising data.
# ##### We have collected the data from an advertising firm which tells us how many dollars were spend on different platforms through advertising.
#
# We are going to analyze the data graphically and numerically to understand that which platform have given us more returns, which platform is stable and monotonous. Finally, we will be performing an optimisation process to check the spending ratios, when advertising dollar has been contrained.
#
# For this project, we’re going to use a  dataset that consists of marketing spend on TV, radio, and Social media, as well as the corresponding dollar sales by period.

# %% [markdown]
# ## Market Mix Modeling
# Marketing mix modeling (MMM) is a statistical analysis such as multivariate regressions on sales and marketing time series data to estimate the impact of various marketing tactics (marketing mix) on sales and then forecast the impact of future sets of tactics. It seeks to determine how much success was generated by each factor, and forecast what future success can be created through altering and optimising the marketing mix.
#
# - <b>The key purpose</b>:
# By estimating the effectiveness of different marketing channels activities, MMM helps to better understand how various marketing activities are driving the business metrics of a product and increase ROI (Return on investment).
#
# MMM is similar to the concept of 4Ps of the marketing mix: Product, Price, Place, Promotion. It’s a fundamental part of marketing theory that considers what factors are required for a business to succeed.
#
#
# # Data Preparation and Data Transformation:
# The industry standard typically will pick a <b>weekly time period</b>. This is because monthly data granularity is too long and daily level data has too much variation which leads to poor accuracy. Therefore, aggregate data at a weekly level is the best practice for creating a MMM model.
#
# # Benefits of Marketing Mix Modelling
# - Enables marketers to prove the ROI (Return of Investment) of their efforts
# - Returns insights that allow for effective budget allocation
# - Facilitates superior sales trend forecasting
#
#
# # Setup
# First, we’re going to import the libraries and read the data, as usual.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, TimeSeriesSplit
import warnings
warnings
# Out:
# <module 'warnings' from '/usr/lib/python3.10/warnings.py'>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**DATASETS**

# %%
df = pd.read_excel("/content/drive/MyDrive/Data Science/Market Mix Modeling/MMM.xlsx",parse_dates=['Date'] , index_col='Date')
df
# Out:
#             TV      Radio  Social_Media Influencer       Sales
# Date
# 2001-01-01  54  14.119060      4.215642       Nano  324.905658
# 2001-01-02  65  26.217056      5.481302      Macro  370.511432
# 2001-01-03  67  16.705375      2.657608      Macro  389.325067
# 2001-01-04  73  31.327127     10.260554       Nano  412.936802
# 2001-01-05  28  17.343639      2.071636      Micro  214.546227
# ...         ..        ...           ...        ...         ...
# 2013-06-14  67  21.723854      4.458475       Mega  313.304629
# 2013-06-15  77  19.370902      3.124065       Nano  350.571846
# 2013-06-16  22  10.606441      0.007274       Nano  158.252974
# 2013-06-17  32   3.171375      0.022745      Macro  196.799056
# 2013-06-18  50   3.147480      2.669657       Nano  260.139232
#
# [4552 rows x 5 columns]

# %%
df.shape
# Out:
# (4552, 5)

# %%
df.Influencer.value_counts()
# Out:
# Mega     1154
# Micro    1149
# Nano     1136
# Macro    1113
# Name: Influencer, dtype: int64

# %% [markdown]
# There are 1154 Mega, 1149 Micro, 1136 Nano and 1113 Macro influencers present in this dataset

# %% [markdown]
# #**Checking for Null Values**

# %%
df.isnull().sum()
# Out:
# TV              0
# Radio           0
# Social_Media    0
# Influencer      0
# Sales           0
# dtype: int64

# %% [markdown]
# Since there are no null values in the dataset, we’re going to look at the variables in the dataset and understand what we’re working with.

# %%
df.describe()
# Out:
#                 TV        Radio  Social_Media        Sales
# count  4552.000000  4552.000000   4552.000000  4552.000000
# mean     54.061731    17.133978      2.948103   296.080006
# std      26.113084     9.171342      2.007434   105.271088
# min      10.000000     0.000684      0.000031    64.148547
# 25%      32.000000     9.789495      1.370759   208.432141
# 50%      53.000000    16.828186      2.664381   290.405681
# 75%      77.000000    24.085183      4.186680   379.831712
# max     100.000000    48.871161     13.981662   545.871974

# %% [markdown]
# #**Checking Correlation**

# %%
sns.set(font_scale=1.4)
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(),cmap='inferno',annot=True)
# Out:
# <ipython-input-9-befccab1c5ee>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap='inferno',annot=True)
# <Axes: >

# %% [markdown]
# From the above plot we can say that initially there is a higher positive correlation between TV and Sales (0.96) than between Radio and Sales (0.85) or Social_Media and Sales (0.54)

# %%
sns.pairplot(df)

# %% [markdown]
# The above plot shows there is a flat correlation between Social Media and Sales, whereas correlation between Radio and Sales is a bit better. And correlation between TV and sales is the best but there are some outliers we can notice.

# %% [markdown]
# #**Linear Regression**
# After storing the data from above in the variable <b>df,</b> , we do the following:

# %%
  # Selecting the X and y variables
X = df.drop(columns=['Sales','Influencer'])
y = df['Sales']

# %%
# Using Cross Validation through Time Series Split and Running Linear Regression
lr = LinearRegression()

# %%
lr.fit(X, y) # refit the model with the complete dataset
print('Coefficients:', lr.coef_)
print('Intercept:', lr.intercept_)
# Out:
# Coefficients: [3.4554708  0.98318562 2.46908408]
# Intercept: 85.14627683442203

# %%
print(cross_val_score(lr, X, y, cv=TimeSeriesSplit()))
# Out:
# [0.9929074  0.87467392 0.68882542 0.84679961 0.88031449]

# %% [markdown]
# #**Checking for Multicolinearity**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = [variance_inflation_factor(X.values, i)

                          for i in range(X.shape[1])]
print(vif)
# Out:
# [17.62849473914493, 20.61633231479259, 4.830879823561631]

# %%
pd.Series(vif, index = X.columns)
# Out:
# TV              17.628495
# Radio           20.616332
# Social_Media     4.830880
# dtype: float64

# %%
lr.fit(X, y) # refit the model with the complete dataset
print('Coefficients:', lr.coef_)
print('Intercept:', lr.intercept_)
# Out:
# Coefficients: [3.4554708  0.98318562 2.46908408]
# Intercept: 85.14627683442203

# %%
print(cross_val_score(lr, X, y, cv=TimeSeriesSplit()))
# Out:
# [0.9929074  0.87467392 0.68882542 0.84679961 0.88031449]

# %%
cv_results = cross_val_score(lr, X, y, cv=TimeSeriesSplit())
np.mean(cv_results)
# Out:
# 0.8567041680084981

# %% [markdown]
# #**Getting the Coefficient and Intercept through OLS:**

# %%
import statsmodels.formula.api as sm
model = sm.ols(formula="Sales ~ TV + Radio + Social_Media", data = df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                 1.685e+04
# Date:                Mon, 11 Mar 2024   Prob (F-statistic):               0.00
# Time:                        17:16:36   Log-Likelihood:                -21977.
# No. Observations:                4552   AIC:                         4.396e+04
# Df Residuals:                    4548   BIC:                         4.399e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       85.1463      1.052     80.904      0.000      83.083      87.210
# TV               3.4555      0.034    101.424      0.000       3.389       3.522
# Radio            0.9832      0.105      9.385      0.000       0.778       1.189
# Social_Media     2.4691      0.281      8.774      0.000       1.917       3.021
# ==============================================================================
# Omnibus:                     1076.006   Durbin-Watson:                   0.572
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18834.161
# Skew:                          -0.663   Prob(JB):                         0.00
# Kurtosis:                      12.876   Cond. No.                         148.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# .summary() provides us  with an abundance of insights on our model. Two main things that are most useful for us in this:
# 1.  The Adj. R-squared is 0.917, which means that almost 92% of all variations in our data can be explained by our model, which is pretty good.
# 2. The p-values for TV, radio and Social_Media are 0.000, which indicates that they have a significant impact on sales.

# %%
from scipy import stats
# normality check
stats.shapiro(model.resid)
# Out:
# ShapiroResult(statistic=0.9171259999275208, pvalue=1.6815581571897805e-44)

# %% [markdown]
# # **Homocedasticity**

# %%
plt.scatter(model.fittedvalues,model.resid)
plt.xlabel("Predicted y values")
plt.ylabel("Residuals")
plt.axhline(0,color = 'red')

# %% [markdown]
# From the values above we are getting this formula:
# ### <b>Sales = 85.1463 + 3.4555 * TV + 0.98 * Radio + 2.469 * Social Media</b>

# %% [markdown]
# #Checking interaction effect between each Variables

# %%
from sklearn.preprocessing import PolynomialFeatures
from statsmodels.regression import linear_model

# Selecting X
X2 = X.copy()
y2 = y.copy()
y2 = list(y2)

# generating interaction terms
x_interaction = PolynomialFeatures(2, interaction_only=True, include_bias=False).fit_transform(X2)

# creating a new dataframe with the intteraction term included
interaction_df = pd.DataFrame(x_interaction, columns = ['TV', 'Radio', 'Social_Media',
                                                       'TV : Radio', 'TV : Social_Media', 'Radio : Social_Media'])

# ceating a linear model and fitting the Dataframe
interaction_model = linear_model.OLS(y2, interaction_df).fit()

# checking p-values
interaction_model.pvalues[interaction_model.pvalues < 0.05]
# Out:
# TV                      0.000000e+00
# Radio                   4.894864e-36
# Social_Media            5.894242e-39
# TV : Radio              4.270327e-99
# TV : Social_Media       5.265578e-28
# Radio : Social_Media    1.603664e-11
# dtype: float64

# %%
model2 = sm.ols(formula="Sales ~ TV : Radio + TV : Social_Media + Radio : Social_Media", data = df).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     9438.
# Date:                Mon, 11 Mar 2024   Prob (F-statistic):               0.00
# Time:                        17:16:37   Log-Likelihood:                -23154.
# No. Observations:                4552   AIC:                         4.632e+04
# Df Residuals:                    4548   BIC:                         4.634e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            179.5653      0.905    198.373      0.000     177.791     181.340
# TV:Radio               0.0977      0.001     91.618      0.000       0.096       0.100
# TV:Social_Media        0.3918      0.013     31.007      0.000       0.367       0.417
# Radio:Social_Media    -1.0885      0.034    -31.953      0.000      -1.155      -1.022
# ==============================================================================
# Omnibus:                      527.334   Durbin-Watson:                   1.215
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3520.816
# Skew:                          -0.338   Prob(JB):                         0.00
# Kurtosis:                       7.255   Cond. No.                     2.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# As we can see there is a presence of interaction term. also, interaction with TV and Radio, TV and Social_Media, Radio and Social_Media proves to be very important for the prediction of Sales as we are getting p-values close to 0 for each interaction.

# %% [markdown]
# # **Breaking Down the Sell**

# %% [markdown]
# To illustrate the computation of the contributions, let us consider a single week:

# %%
Original_week = df.iloc[[196]]
Original_week
# Out:
#             TV      Radio  Social_Media Influencer       Sales
# Date
# 2001-07-16  84  27.817582      6.171058      Micro  450.741646

# %%
print(lr.predict(([[84.0, 27.817582, 6.171058, ]])))
# Out:
# [417.99253206]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# This is exectly not the true answer of 450.741646 from the table above, but let us stick with it for now. We can now see that the (unadjusted) contribution of TV is

# %% [markdown]
# #***coef_TV * Spending_TV = 3.455 * 84 = 290.22***
# #***coef_Radio * Spending_Radio = 0.98 * 27.817582 = 27.261230036***
# #***coef_Social_Media * Spending_Social_Media = 2.4691 * 6.171058 = 15.2369593078***

# %% [markdown]
# and for the other channels accordingly. Now,the contributions sum up to the model prediction 417.99253206, which is not the true target of 450.741646, so let us just multiply the contribution of baseline by a correction factor of:
# **correction_factor =  450.741646 / 417.99253206 ≈ 1.078** and everything is fine. We get
#
#
# #***contribution_TV = correction_factor * 290.22 = 312.857***

# %% [markdown]
# Also we get
# * contribution_radio = correlation_factor * 27.26123036 = 29.3876 and
# * contribution_Social_media = correlation_factor * 15.236959 = 16.425
# * base = 91.7877114
#
# Adding everything up yields the observed label, as we want it:
#
# # 312.857 + 29.3876 + 16.425 + 91.7877114 = 450.457.

# %% [markdown]
# # **Contribution plot for all observations**

# %%
weights = pd.Series(lr.coef_,index=X.columns)
base = lr.intercept_
unadj_contributions = X.mul(weights).assign(Base=base)
adj_contributions = (unadj_contributions
                     .div(unadj_contributions.sum(axis=1), axis=0)
                     .mul(y, axis=0)
                    ) # contains all contributions for each day
ax = ax = (adj_contributions[['Base', 'Social_Media', 'Radio', 'TV']].plot.area(figsize=(16, 10),
                                                                                linewidth=1,title='Predicted Sales and Breakdown',
                                                                                ylabel='Sales',xlabel='Date'))
handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles[::-1], labels[::-1],
    title='Channels', loc="center left",
    bbox_to_anchor=(1.01, 0.5)
)

# %% [markdown]
# We can see (or compute) that the baseline is around 80 sales each day, Social Media contributes around 80-100 on average whenever it is active,Radio contributes around 100-150 on average whenever it is active ,  and TV contributes around 150- 450 when it is active.
#
# <b>Note</b>: - One interesting thing we can notice from the chart, that base is supposed to be constant, but it is fluctuating. Because for each observation the correction factor for the intercept is changing, thats why we are seeing this fluctuation.
#
# # Computing the Return on Investment (ROI)
# We can now determine which channel was the best in terms of ROI, a number that measures the efficiency. The formula is simple:
# ## channel_ROI = Sales from the channel / channel spendings
#
# - Calculating the TV ROI

# %%
sales_from_tv = adj_contributions['TV'].sum()
spendings_on_tv = df['TV'].sum()
tv_roi = sales_from_tv / spendings_on_tv
tv_roi
# Out:
# 3.456317384842416

# %% [markdown]
# An ROI less than 1 means that the channel performed poorly. For the TV ROI we can say:
# > ## For each 1 $ we spent on TV, we got 3 dollars 46 cents back.

# %% [markdown]
# - Calculating the Radio ROI

# %%
sales_from_radio = adj_contributions['Radio'].sum()
spendings_on_radio = df['Radio'].sum()
radio_roi = sales_from_radio / spendings_on_radio
radio_roi
# Out:
# 0.9822807902564936

# %% [markdown]
# - Calculating the Social Media ROI

# %%
sales_from_Social_Media = adj_contributions['Social_Media'].sum()
spendings_on_Social_Media = df['Social_Media'].sum()
Social_Media_roi = sales_from_Social_Media / spendings_on_Social_Media
Social_Media_roi
# Out:
# 2.465709000491316

# %% [markdown]
# From the above results we can see, TV and Social Media has an ROI of 3.46 and 2.47 which is much better, it seems that these channels worked quite well in the time period that we considered.
#
# # Problems With This Simple Approach
# While the above approach seems reasonable, it has certain shortcomings that we have to address:
# 1. The performance could be better. Sometimes, there is nothing we can do about bad performance because it depends on the data a lot, but we should try our best anyway.
# 2. Even more severe: The model itself definitely does not reflect reality. According to the linear formula, we can drive sales as high as we want by spending more and more money on advertising. Since the TV and Social Media have a high coefficient of 3.46 and 2.47, for each 1 $ we spend in these channels we generate additional sales of 3.46 dollars on TV and 2.47 dollars on Social Media. Repeat for infinite money, customers will hate this trick!
# 3. Optimizing becomes trivial and unrealistic as well. To maximize sales, we would now put all the money into the Tv and Social Media channels because they have the highest coefficients among the three. We would abandon radio advertising altogether which may be not the right thing to do if the company wants to retain its awareness among people.

# %% [markdown]
# # Creating Dummy Variables for Influencer
# Since there are 4 distinct classes that are present within this variable, we will one-hot encode and split this into 4 different binary variables to indicate the kind of influencer used for the corresponding sales.
# - <b>Note</b>: we actually only need (n-1) dummy variables for a categorical variable with n classes by logic that the classes are mutually exclusive and collectively exhaustive. For eg., if a Sale did not use Macro, Micro or Nano influencer, it is understood by default that it used a Mega influencer, thereby negating the need for a fourth binary indicator variable for Mega.

# %%
# Dummmy variable for Influencer
infl = pd.get_dummies(df.Influencer)
# Binding it back to original dataset and dropping categorical variable Influencer
model_data = pd.concat([df, infl], axis = 1)
model_data.drop('Influencer', inplace = True, axis = 1)
model_data.head()
# Out:
#             TV      Radio  Social_Media       Sales  Macro  Mega  Micro  Nano
# Date
# 2001-01-01  54  14.119060      4.215642  324.905658      0     0      0     1
# 2001-01-02  65  26.217056      5.481302  370.511432      1     0      0     0
# 2001-01-03  67  16.705375      2.657608  389.325067      1     0      0     0
# 2001-01-04  73  31.327127     10.260554  412.936802      0     0      0     1
# 2001-01-05  28  17.343639      2.071636  214.546227      0     0      1     0

# %%
X1 = model_data.loc[:, model_data.columns != 'Sales']
X1 = X1.loc[:, X1.columns != 'Mega']
y1 = model_data['Sales']

# %%
X1
# Out:
#             TV      Radio  Social_Media  Macro  Micro  Nano
# Date
# 2001-01-01  54  14.119060      4.215642      0      0     1
# 2001-01-02  65  26.217056      5.481302      1      0     0
# 2001-01-03  67  16.705375      2.657608      1      0     0
# 2001-01-04  73  31.327127     10.260554      0      0     1
# 2001-01-05  28  17.343639      2.071636      0      1     0
# ...         ..        ...           ...    ...    ...   ...
# 2013-06-14  67  21.723854      4.458475      0      0     0
# 2013-06-15  77  19.370902      3.124065      0      0     1
# 2013-06-16  22  10.606441      0.007274      0      0     1
# 2013-06-17  32   3.171375      0.022745      1      0     0
# 2013-06-18  50   3.147480      2.669657      0      0     1
#
# [4552 rows x 6 columns]

# %% [markdown]
# here we are taking base influencer as Mega, otherwise we would get negative coefficients in Macro, Micro and Nano. So we have removed Mega from X variable to take it as a base influencer.
#
# # Splitting the data into Train and Test

# %% [markdown]
# We are splitting the dataset into arrays of dependent (Y) and independent (X) variables to be fed into the model. Since Regression (Estimation) is a supervised learning method, we have the concept of Train and Test sets here. We will use 65% of the dataset to train the Machine Learning model. Once the model has been trained, we use the remaining 35% of the dataset that is alien to it, and gauge whether it is able to correctly predict the Sales, given the marketing spends for data it hasn’t seen before.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size = 0.35, random_state = 101)
# Random state set to 101 to get same results in every iteration

# %% [markdown]
# # Train the Model

# %%
lr2 = LinearRegression()
lr2.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
train = pd.concat([X_train, y_train],
                  axis = 1)

# %%
model3 = sm.ols(formula="Sales ~ TV	+ Radio	+ Social_Media + C(Macro) + C(Micro) + C(Nano)", data = train).fit()
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     5668.
# Date:                Mon, 11 Mar 2024   Prob (F-statistic):               0.00
# Time:                        17:16:39   Log-Likelihood:                -14228.
# No. Observations:                2958   AIC:                         2.847e+04
# Df Residuals:                    2951   BIC:                         2.851e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        83.3939      1.585     52.627      0.000      80.287      86.501
# C(Macro)[T.1]     2.6296      1.554      1.692      0.091      -0.417       5.676
# C(Micro)[T.1]     0.7385      1.544      0.478      0.632      -2.288       3.765
# C(Nano)[T.1]      1.5437      1.537      1.004      0.315      -1.470       4.557
# TV                3.4541      0.042     81.672      0.000       3.371       3.537
# Radio             0.9757      0.130      7.488      0.000       0.720       1.231
# Social_Media      2.6124      0.342      7.639      0.000       1.942       3.283
# ==============================================================================
# Omnibus:                      643.533   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12265.072
# Skew:                          -0.522   Prob(JB):                         0.00
# Kurtosis:                      12.921   Cond. No.                         281.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Results and Evaluation

# %%
# print the intercept
print(lr2.intercept_)
# Out:
# 83.39391259986061

# %%
coef_df = pd.DataFrame(lr2.coef_, X1.columns, columns = ['Coefficient'])
coef_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_334c3_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_334c3_row1_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_334c3_row2_col0 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_334c3_row3_col0 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_334c3_row4_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_334c3_row5_col0 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# </style>
# <table id="T_334c3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_334c3_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_334c3_level0_row0" class="row_heading level0 row0" >TV</th>
#       <td id="T_334c3_row0_col0" class="data row0 col0" >3.454105</td>
#     </tr>
#     <tr>
#       <th id="T_334c3_level0_row1" class="row_heading level0 row1" >Radio</th>
#       <td id="T_334c3_row1_col0" class="data row1 col0" >0.975709</td>
#     </tr>
#     <tr>
#       <th id="T_334c3_level0_row2" class="row_heading level0 row2" >Social_Media</th>
#       <td id="T_334c3_row2_col0" class="data row2 col0" >2.612431</td>
#     </tr>
#     <tr>
#       <th id="T_334c3_level0_row3" class="row_heading level0 row3" >Macro</th>
#       <td id="T_334c3_row3_col0" class="data row3 col0" >2.629586</td>
#     </tr>
#     <tr>
#       <th id="T_334c3_level0_row4" class="row_heading level0 row4" >Micro</th>
#       <td id="T_334c3_row4_col0" class="data row4 col0" >0.738496</td>
#     </tr>
#     <tr>
#       <th id="T_334c3_level0_row5" class="row_heading level0 row5" >Nano</th>
#       <td id="T_334c3_row5_col0" class="data row5 col0" >1.543664</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Interpreting the Coefficients
# If we take a closer look above we understand that the spends on TV have a positive causal relationship with sales, as an increase of 1 Mn dollars in TV spends has an effect of 3.45 Mn increase in Sales. It is however interesting to note that Radio and Social media also have a positive impact on Sales as they increase the sales by 0.97 Mn and 2.61 Mn dollars with every additional 1 Mn dollars spent.
# Now since Macro, Micro and Nano are binary variables, what their coefficients mean is that whenever the variable is flagged 1, i.e. suppose a Macro influencer was used, sales increased by around $2.63 Mn.

# %%
plt.figure(figsize = (10,5))

# predicting Sales for the test set
y_pred = lr2.predict(X_test)

# Plotting Predicted values vs actual values available for the test set
plt.scatter(y_test, y_pred, c = 'blue')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
# Out:
# Text(0, 0.5, 'Predicted Sales')

# %% [markdown]
# The above chart shows us that the predicted values are less than the actual values, means it is a little bit underfitting

# %% [markdown]
# # Evaluating the Model

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R-Square:',metrics.r2_score(y_test,y_pred))
# Out:
# MAE: 25.915060314272694
# MSE: 972.1516530307853
# RMSE: 31.17934657799591
# R-Square: 0.9126916704947571

# %% [markdown]
# ## Some popular metrics used to evaluate linear regression models are calculated above. Highlighting on the most pertinent ones —
# 1. RSquare of 0.91 implies that the independent variables i.e. the marketing spends across the channels are able to successfully explain 91% of the variability seen in Sales across the dataset.
# 2. Mean absolute error (MAE) is calculated as the mean of the absolute difference in the predicted sales of the test dataset and the actual values of Sales given. Here, there is a fluctuation of about 25.915 Mn dollars between the predicted and actual values of Sales.
# 3. Root Mean Square error (RMSE) is another transformed variation of measuring the fluctuations between actual and predicted sales. It is found to be $31.17 Mn, which is also close to the MAE reported.
#
#
# In conclusion, the linear model has performed average.

# %% [markdown]
# # Feature importance with Random Forest
# <b>Note</b>: - Random forest is normally used for both classification & regression purpose, but here we are not fitting the data into Random forest for classification. We are using RandomForestRegressor to get the feature importance, that describes which features are relevant. It can help with better understanding of the solved problem and sometimes lead to model improvements by employing the feature selection. We can read more from [here](https://mljar.com/blog/feature-importance-in-random-forest/).

# %%
# Building the Random Forest Model
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error as mae

# Cross Validation through Train Test Split
from sklearn.model_selection import train_test_split
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size=.25, random_state=0)

model4 = RandomForestRegressor(random_state=1)
model4.fit(X_train2, y_train2)
pred = model4.predict(X_test2)

# Visualizing Feature Importance
feat_importances = pd.Series(model4.feature_importances_, index=X.columns)
feat_importances.nlargest(25).plot(kind='barh',figsize=(10,10))
# Out:
# <Axes: >

# %%
feat_importances
# Out:
# TV              0.923749
# Radio           0.038017
# Social_Media    0.038233
# dtype: float64

# %% [markdown]
# There seems to be a pattern, where TV is the most important, followed by
#
# ---
#
# Social_Media, leaving radio last.

# %% [markdown]
# # Identifying the best model
# Next, we’ll test a load of different regression models to see which one delivers the best results. The quickest and easiest way to do this is to place all the model parameters in a Python dictionary and then loop over them.

# %% [markdown]
# - ## Importing Packages

# %%
import time
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lars
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import HuberRegressor
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import OrthogonalMatchingPursuit
from sklearn.svm import SVR
from sklearn.svm import NuSVR
from sklearn.svm import LinearSVR
from sklearn.kernel_ridge import KernelRidge
from sklearn.isotonic import IsotonicRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_decomposition import PLSRegression

# %% [markdown]
# - ## Scaling the data
# To help improve the model results, it’s worth using a scaling or normalisation technique on the data, especially if it’s skewed. Ours is not too bad, but we’ve passed it through StandardScaler() to be sure.

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# - ## Training the models

# %% [markdown]
# Next we will place 19 differnet algorithms in a dictionary, later we will fit this regressors with our x_train and y_train.

# %%
regressors = {
    "XGBRegressor": XGBRegressor(booster='gblinear', objective ='reg:squarederror', verbosity = 0, random_state=42),
    # reg:linear is now deprecated in favor of reg:squarederror
    # booster='gblinear' because by default it is set to 'gbtree'. 'gbtree' won't give us coefficients
    # verbosity = 0 -> Verbosity of printing messages. Valid values are 0 (silent/ignore errors), 1 (warning), 2 (info), 3 (debug).
    "RandomForestRegressor": RandomForestRegressor(),
    "DecisionTreeRegressor": DecisionTreeRegressor(),
    "GaussianProcessRegressor": GaussianProcessRegressor(),
    "SVR": SVR(),
    "NuSVR": NuSVR(),
    "LinearSVR": LinearSVR(),
    "KernelRidge": KernelRidge(),
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lars": Lars(),
    "TheilSenRegressor": TheilSenRegressor(),
    "HuberRegressor": HuberRegressor(),
    "PassiveAggressiveRegressor": PassiveAggressiveRegressor(),
    "ARDRegression": ARDRegression(),
    "BayesianRidge": BayesianRidge(),
    "ElasticNet": ElasticNet(),
    "OrthogonalMatchingPursuit": OrthogonalMatchingPursuit(),
    "pls": PLSRegression(),
}

# %% [markdown]
# We’ll create a Pandas dataframe called df_models and now loop through the regressors, fit each one to the data, and return the Root Mean Squared Error of a 10-fold cross validation to the dataframe, and then display the output.

# %%
import warnings
warnings.filterwarnings("ignore")  # doesn't spam the notebook with warnings

df_models = pd.DataFrame(columns=['model', 'run_time', 'rmse', 'rmse_cv'])
for key in regressors:
    #print('*',key)
    start_time = time.time()
    regressor = regressors[key]
    model5 = regressor.fit(X_train, y_train)
    y_pred = model5.predict(X_test)

    scores = cross_val_score(model5, X_train, y_train, scoring="neg_mean_squared_error", cv=10)

    row = {'model': key,'run_time': format(round((time.time() - start_time)/60,7)),
           'rmse': round(np.sqrt(mean_squared_error(y_test, y_pred))),'rmse_cv': round(np.mean(np.sqrt(-scores)))}

    df_models = df_models.append(row, ignore_index=True)

# %% [markdown]
# # Printing each and every regressors with run time, rmse and rmse_cv
# rmse = root mean square error\
# rmse_cv = root mean square error cross validation

# %%
df_models.head(20).sort_values(by='rmse_cv', ascending=True)
# Out:
#                          model   run_time  rmse rmse_cv
# 0                 XGBRegressor   0.005882    31      30
# 15               BayesianRidge  0.0016767    31      30
# 14               ARDRegression  0.0042899    31      30
# 12              HuberRegressor  0.0034314    31      30
# 10                        Lars  0.0016646    31      30
# 8             LinearRegression  0.0019095    31      30
# 9                        Ridge  0.0020752    31      30
# 17   OrthogonalMatchingPursuit  0.0015006    32      31
# 1        RandomForestRegressor  0.2036737    32      31
# 6                    LinearSVR  0.0007787    35      33
# 18                         pls  0.0013018    35      33
# 13  PassiveAggressiveRegressor   0.000945    38      33
# 16                  ElasticNet  0.0012618    41      40
# 2        DecisionTreeRegressor  0.0039741    43      41
# 4                          SVR  0.1013323    43      42
# 11           TheilSenRegressor  0.1824372    45      42
# 5                        NuSVR  0.0544184    44      44
# 7                  KernelRidge  0.1046952   298     298
# 3     GaussianProcessRegressor  0.2909849  4877   10011

# %% [markdown]
# The first outcome i.e. Ridge Regressor is the best model for out dataset
# Now predicting y value with help of x_test.
#
# <b>RidgeRegression</b>: It is a <b>Regularization Method</b> to reduce <b>Overfitting.</b>

# %% [markdown]
# # Choosing best alpha for Ridge regression

# %%
from sklearn.linear_model import RidgeCV

# Choosing best alpha for ridge regression with Leave one out cross-validation
ridge_cv = RidgeCV(alphas=(0.01, 0.1, 1, 10, 100), scoring='neg_mean_squared_error', store_cv_values=True).fit(X_train, y_train)

# Best alpha
ridge_cv.alpha_
# Out:
# 0.1

# %% [markdown]
# # Train the model with best alpha value

# %%
regressor = Ridge(alpha=0.1)
model6 = regressor.fit(X_train, y_train)
y_pred = model6.predict(X_test)
y_pred
# Out:
# array([131.73658429, 339.02167081, 247.57944893, ..., 255.39365167,
#        263.03041359, 473.15086952])

# %% [markdown]
# # Defining Actual and Predicted values

# %%
test2 = pd.DataFrame({'Predicted sales':y_pred, 'Actual sales':y_test})
fig = plt.figure(figsize = (16,8))
test2 = test2.reset_index()
test2 = test2.drop(['Date'], axis=1)
plt.plot(test2[:50])
plt.legend(['Actual sales', 'Predicted sales'])

# %% [markdown]
# This model works, but it’s only crude given the complexity of many MMMs. To further improve this, there are a whole load of other things we could do. Firstly, we could add some lagged data, by using shift to get the channel spend in the previous days to see if that’s correlated to sales in future periods. We could also do some hyperparameter tuning, or add in some additional regressors if we have them.
#
# # Fixing the Problems
# To circumvent these problems, we can do some clever feature engineering that allows us to incorporate some marketing domain knowledge into the model. The following techniques will improve performance as well as making the model more realistic.

# %% [markdown]
# # Advertising Adstock
# This feature engineering that we will do is a crucial component called the advertising adstock, a term coined by Simon Broadbent [1]. It is a fancy word that encapsulates two simple concepts:
# 1. We assume that the more money you spend on advertising, the higher your sales get. However, the increase gets weaker the more we spend. For example, increasing the TV spends from 0 € to 100,000 € increases our sales a lot, but increasing it from 100,000,000 € to 100,100,000 € does not do that much anymore. This is called <b>a saturation effect</b> or <b>the effect of diminishing returns</b>.
# 2. If we spend money on advertising week T, often people will not immediately buy your product, but a few (let us say x) weeks later. This is because the product might be expensive, and people want to think about it carefully or compare it to similar products from other companies. Whatever the reason might be, the sale in week T + x is partially caused by the advertising you played in week T, so it should also get some credits. This is called the <b>carry-over</b> or <b>lagged effect</b>.
#
# Our new model is still linear, but with adstock features instead of raw spendings as input. This makes the model much stronger while keeping it interpretable.

# %% [markdown]
# # Building Saturation and Carry-Over Effects in scikit-learn
# Unfortunately for us, scikit-learn does not contain these transformations because they are not of cross-industry interest. But since both transformations are not that complicated it is a nice opportunity to practice writing scikit-learn compatible estimators.
#
# # Creating a Saturation Effect
# We want to create a transformation (=mathematical function) with the following properties:
# 1. If the spendings are 0, the saturated spendings are also 0.
# 2. The transformation is monotonically increasing, i.e. the higher the input spendings, the higher the saturated output spendings.
# 3. The saturated values do not grow to infinity. Instead, they are upper bounded by some number, let us say 1.
# In short, we want something like this:\
# ![image](https://miro.medium.com/max/700/1*5I09TDswHmIJ76DlbaozAg.png)
#
# There are many ways to get functions like this, in the picture we see the function 1-exp(-0.7x), for example. So let us just use this function template and generalize it to 1-exp(-ax) for some a > 0. a is a hyperparameter that we can tune afterward because usually, we do not know the shape of the saturation function.
# > <b>Note</b>: There are many more standard saturations functions, such as the Adbudg and Hill functions, but let us stick with the exponential function for simplicity.
#
# <b>A nice side-effect</b>: We are able to output the saturation curves in the end, so we know if it makes sense to spend more money or if the channel is saturated already. From the picture above, for example, it seems like investing more than 8 is useless.

# %%
class ExponentialSaturation:
    def __init__(self, a=1.):
        self.a = a

    def transform(self, X):
        return 1 - np.exp(-self.a*X)

# %% [markdown]
# However, we will add some sanity checks for the inputs to make it scikit-learn compliant. This bloats up the code a bit, but it is a comparatively small price that we have to pay.

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.utils.validation import check_is_fitted, check_array
class ExponentialSaturation(BaseEstimator, TransformerMixin):
    def __init__(self, a=1.):
        self.a = a

    def fit(self, X, y=None):
        X = check_array(X)
        self._check_n_features(X, reset=True) # from BaseEstimator
        return self
    def transform(self, X):
        check_is_fitted(self)
        X = check_array(X)
        self._check_n_features(X, reset=False) # from BaseEstimator
        return 1 - np.exp(-self.a*X)

# %% [markdown]
# It is still not perfect because we should also implement a check for a being larger than zero, but this is something we can easily do on our own. With the ExponentialSaturation transformer, we can do the following:
#
# ![image](https://miro.medium.com/max/452/1*hgHVvbOuRoQyMxW2mUNZww.png)
#
# Let us now move on to the next effect.
#
# # Creating a Carry-Over Effect
# This one is slightly more tricky. Let us use an example to understand what we want to achieve. We are given a series of spendings over time such as
# ### (16, 0, 0, 0, 0, 4, 8, 0, 0, 0),
# meaning that we spent 16 in the first week, then we spent nothing from week 2 to 5, then we spent 4 in week 6, etc.
#
# We now want that spendings in one week to get partially carried over to the next weeks in an exponential fashion. This means: In week 1 there is a spend of 16. Then we carry over 50%, meaning
# - 0.5 * 16 = 8 to week 2,
# - 0.5² * 16 = 4 to week 3,
# - 0.5³ * 16 = 2 to week 4,
# - …
#
# ## This introduces two hyperparameters:
# <b>The strength (how much gets carried over?)</b> and <b>the length</b> (how long does it get carried over?) of the carry-over effect. If we use a strength of 50% and a length of 2, the spending sequence from above becomes
# ### (16, 8, 4, 0, 0, 4, 10, 5, 2, 0).

# %%
from scipy.signal import convolve2d
import numpy as np
class ExponentialCarryover(BaseEstimator, TransformerMixin):
    def __init__(self, strength=0.5, length=1):
        self.strength = strength
        self.length = length
    def fit(self, X, y=None):
        X = check_array(X)
        self._check_n_features(X, reset=True)
        self.sliding_window_ = (
            self.strength ** np.arange(self.length + 1)
        ).reshape(-1, 1)
        return self
    def transform(self, X: np.ndarray):
        check_is_fitted(self)
        X = check_array(X)
        self._check_n_features(X, reset=False)
        convolution = convolve2d(X, self.sliding_window_)
        if self.length > 0:
            convolution = convolution[: -self.length]
        return convolution

# %% [markdown]
# We can see that the class takes the strength and length. During the fit it creates a sliding window that gets used by the convolve2d function, doing magically just what we want. If we know convolutional layers from CNNs, this is exactly what happens here. Graphically, it does the following:
#
# ![image](https://miro.medium.com/max/656/1*8AEZKG-bjymGEHHa-k-YuQ.gif)
#
# > <b>Note</b>: There are many more ways to create a carryover as well. The decay does not have to be exponential. And maybe the peak of the advertising effect is not reached on the day the money was spent, but always the next week. We can express all of these variations by changing the sliding window accordingly.
# Let us combine both saturation and carry-over effects to create a more realistic marketing mix model.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Applying adstock effects to each channel via Pipeline with ColumnTransformer
adstock =ColumnTransformer(
    [
     ('tv_pipe', Pipeline([
                           ('carryover', ExponentialCarryover()),
                           ('saturation', ExponentialSaturation())
     ]), ['TV']),
     ('radio_pipe', Pipeline([
                           ('carryover', ExponentialCarryover()),
                           ('saturation', ExponentialSaturation())
     ]), ['Radio']),
     ('Social_Media_pipe', Pipeline([
                           ('carryover', ExponentialCarryover()),
                           ('saturation', ExponentialSaturation())
     ]), ['Social_Media']),
     ('Macro_pipe', Pipeline([
                           ('carryover', ExponentialCarryover()),
                           ('saturation', ExponentialSaturation())
     ]), ['Macro']),
     ('Micro_pipe', Pipeline([
                           ('carryover', ExponentialCarryover()),
                           ('saturation', ExponentialSaturation())
     ]), ['Micro']),
     ('Nano_pipe', Pipeline([
                           ('carryover', ExponentialCarryover()),
                           ('saturation', ExponentialSaturation())
     ]), ['Nano']),
    ],
    remainder='passthrough'
)

# Creating a new model with adstock effects
model7 = Pipeline([
                  ('adstock', adstock),
                  ('regression', Ridge(alpha=0.1))
])

# %%
# Setting up with X and y variables
X2 = X1.copy()
y2 = y1.copy()

#Fitting X and y variable into the new model
model7.fit(X2, y2)
# Out:
# Pipeline(steps=[('adstock',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('tv_pipe',
#                                                   Pipeline(steps=[('carryover',
#                                                                    ExponentialCarryover()),
#                                                                   ('saturation',
#                                                                    ExponentialSaturation())]),
#                                                   ['TV']),
#                                                  ('radio_pipe',
#                                                   Pipeline(steps=[('carryover',
#                                                                    ExponentialCarryover()),
#                                                                   ('saturation',
#                                                                    ExponentialSaturation())]),
#                                                   ['Radio']),
#                                                  ('Social_Media_pipe',
#                                                   Pipeline(steps...
#                                                   Pipeline(steps=[('carryover',
#                                                                    ExponentialCarryover()),
#                                                                   ('saturation',
#                                                                    ExponentialSaturation())]),
#                                                   ['Macro']),
#                                                  ('Micro_pipe',
#                                                   Pipeline(steps=[('carryover',
#                                                                    ExponentialCarryover()),
#                                                                   ('saturation',
#                                                                    ExponentialSaturation())]),
#                                                   ['Micro']),
#                                                  ('Nano_pipe',
#                                                   Pipeline(steps=[('carryover',
#                                                                    ExponentialCarryover()),
#                                                                   ('saturation',
#                                                                    ExponentialSaturation())]),
#                                                   ['Nano'])])),
#                 ('regression', Ridge(alpha=0.1))])

# %%
print(cross_val_score(model7, X2, y2, cv = TimeSeriesSplit()).mean())
# Out:
# 0.017147981656106516

# %% [markdown]
# It works!
# # Hyperparameter Tuning
# We will use Optuna, an advanced library for optimization task. Among many other things, it offers a scikit-learn-compatible OptunaSearchCV class that we can see as a drop-in replacement of sckit-learn's GridSearchCV and RandomizedSearchCV .
# In a nutsell, OptumaSearch is a much smarter
# version of RandomizedSearchCV. While RandomizedSearchCV walks around randomly only, OptunaSearchCV walks around randomly at first, but then checks hyperparameter combinations that look most promissing.

# %%
# Installing the required module via pip
# !pip install optuna==2.10.1
# Out:
# Collecting optuna==2.10.1
#   Downloading optuna-2.10.1-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.2/308.2 kB 2.5 MB/s eta 0:00:00
# Collecting alembic (from optuna==2.10.1)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 16.0 MB/s eta 0:00:00
# Collecting cliff (from optuna==2.10.1)
#   Downloading cliff-4.6.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 9.6 MB/s eta 0:00:00
# Collecting cmaes>=0.8.2 (from optuna==2.10.1)
#   Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Collecting colorlog (from optuna==2.10.1)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna==2.10.1) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna==2.10.1) (23.2)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.10/dist-packages (from optuna==2.10.1) (1.11.4)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from optuna==2.10.1) (2.0.28)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna==2.10.1) (4.66.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna==2.10.1) (6.0.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.1.0->optuna==2.10.1) (4.10.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.1.0->optuna==2.10.1) (3.0.3)
# Collecting Mako (from alembic->optuna==2.10.1)
#   Downloading Mako-1.3.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from cliff->optuna==2.10.1) (3.10.0)
# Collecting autopage>=0.4.0 (from cliff->optuna==2.10.1)
#   Downloading autopage-0.5.2-py3-none-any.whl (30 kB)
# Collecting cmd2>=1.0.0 (from cliff->optuna==2.10.1)
#   Downloading cmd2-2.4.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.2/147.2 kB 14.4 MB/s eta 0:00:00
# Collecting stevedore>=2.0.1 (from cliff->optuna==2.10.1)
#   Downloading stevedore-5.2.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.10/dist-packages (from cmd2>=1.0.0->cliff->optuna==2.10.1) (23.2.0)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.10/dist-packages (from cmd2>=1.0.0->cliff->optuna==2.10.1) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from cmd2>=1.0.0->cliff->optuna==2.10.1) (0.2.13)
# Collecting pbr!=2.1.0,>=2.0.0 (from stevedore>=2.0.1->cliff->optuna==2.10.1)
#   Downloading pbr-6.0.0-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic->optuna==2.10.1) (2.1.5)
# Installing collected packages: pbr, Mako, colorlog, cmd2, cmaes, autopage, stevedore, alembic, cliff, optuna
# Successfully installed Mako-1.3.2 alembic-1.13.1 autopage-0.5.2 cliff-4.6.0 cmaes-0.10.0 cmd2-2.4.3 colorlog-6.8.2 optuna-2.10.1 pbr-6.0.0 stevedore-5.2.0

# %%
from optuna.integration import OptunaSearchCV
from optuna.distributions import UniformDistribution, IntUniformDistribution

# Implementing AdStock parameters on the previously fitted model using OptunaSearchCV
tuned_model = OptunaSearchCV(
    estimator = model7,
    param_distributions={
        'adstock__tv_pipe__carryover__strength': UniformDistribution(0, 1),
        'adstock__tv_pipe__carryover__length': IntUniformDistribution(0, 6),
        'adstock__tv_pipe__saturation__a': UniformDistribution(0, 0.01),
        'adstock__radio_pipe__carryover__strength': UniformDistribution(0, 1),
        'adstock__radio_pipe__carryover__length': IntUniformDistribution(0, 6),
        'adstock__radio_pipe__saturation__a': UniformDistribution(0, 0.01),
        'adstock__Social_Media_pipe__carryover__strength': UniformDistribution(0, 1),
        'adstock__Social_Media_pipe__carryover__length': IntUniformDistribution(0, 6),
        'adstock__Social_Media_pipe__saturation__a': UniformDistribution(0, 0.01),
        'adstock__Macro_pipe__carryover__strength': UniformDistribution(0, 1),
        'adstock__Macro_pipe__carryover__length': IntUniformDistribution(0, 6),
        'adstock__Macro_pipe__saturation__a': UniformDistribution(0, 0.01),
        'adstock__Micro_pipe__carryover__strength': UniformDistribution(0, 1),
        'adstock__Micro_pipe__carryover__length': IntUniformDistribution(0, 6),
        'adstock__Micro_pipe__saturation__a': UniformDistribution(0, 0.01),
        'adstock__Nano_pipe__carryover__strength': UniformDistribution(0, 1),
        'adstock__Nano_pipe__carryover__length': IntUniformDistribution(0, 6),
        'adstock__Nano_pipe__saturation__a': UniformDistribution(0, 0.01),
    },
    n_trials=100,
    cv=TimeSeriesSplit(),
    random_state=0
)

# estimator – Object to use to fit the data.
# param_distributions – Dictionary where keys are parameters and values are distributions.
# Distributions are assumed to implement the optuna distribution interface.
# n_trials = Number of iterators
# cv – Cross-validation strategy.

# For more details: https://optuna.readthedocs.io/en/stable/reference/generated/optuna.integration.OptunaSearchCV.html
# see the example part of the above link it shows how using optuna search cv is helping to tune the support vector machine.

# %% [markdown]
# We tell Optuna to optimize model . It does so by using all parameters we specify in param_distributions . Because our model is quite nested, i.e. there are pipelines in a column transformer that itself is in a pipeline again, we have to specify exactly which hyperparameter we want to tune. This is done via strings such as adstock__tv_pipe__carryover__strength , where two underscores separate different levels of the complete model. We find the words adstock , tv_pipe , carryover all in the model specification, while strength is a parameter of the ExponentialCarryover transformer.\
# Then, we find some distributions. UniformDistribution(0, 1) means that it should look for float parameters between 0 and 1. By the same logic, IntUniformDistribution(0, 6) searches for integer values between 0 and 6 (not 5!), thus we tell the model to only consider carryover length less or equal to six weeks, which is just a choice we make.\
# We try n_trials=1000 different combinations of parameters and evaluate using a TimeSeriesSplit again. Keep the results reproducible by setting random_state=0 . Done! This should be enough to understand the code.
# # Performance Check
# Let us check the performance using this optimized model named tuned_model . It takes a long time. We can reduce the n_trials to 100 to get a worse solution much faster.

# %%
# Checking optimal cross validation accuracy through TimeSeriesSplit Cross validation
print(cross_val_score(tuned_model, X2, y2, cv=TimeSeriesSplit()).mean())
# Out:
# [I 2024-03-11 17:17:53,415] A new study created in memory with name: no-name-441aa452-6076-4134-97ed-d56fc2c2f1f3
# [I 2024-03-11 17:17:53,619] Trial 0 finished with value: 0.7929426947518272 and parameters: {'adstock__tv_pipe__carryover__strength': 0.4860473230215504, 'adstock__tv_pipe__carryover__length': 4, 'adstock__tv_pipe__saturation__a': 0.009855760506615989, 'adstock__radio_pipe__carryover__strength': 0.1955964101622225, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.00980582177099305, 'adstock__Social_Media_pipe__carryover__strength': 0.18048029738995275, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.008463095456331128, 'adstock__Macro_pipe__carryover__strength': 0.7967092952533198, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.00517502161880338, 'adstock__Micro_pipe__carryover__strength': 0.04182737713424278, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.0014206610097397077, 'adstock__Nano_pipe__carryover__strength': 0.07832671372998268, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.006592437999535571}. Best is trial 0 with value: 0.7929426947518272.
# [I 2024-03-11 17:17:53,826] Trial 1 finished with value: 0.8364630759313576 and parameters: {'adstock__tv_pipe__carryover__strength': 0.35725476168521175, 'adstock__tv_pipe__carryover__length': 6, 'adstock__tv_pipe__saturation__a': 0.001651149068523966, 'adstock__radio_pipe__carryover__strength': 0.9192135617465139, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.0017677763778372825, 'adstock__Social_Media_pipe__carryover__strength': 0.5057684183863022, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.009897365793712223, 'adstock__Macro_pipe__carryover__strength': 0.6947000513172431, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0008235858666189444, 'adstock__Micro_pipe__carryover__strength': 0.25690484812921544, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.007316067473600314, 'adstock__Nano_pipe__carryover__strength': 0.06991967936105048, 'adstock__Nano_pipe__carryover__length': 0, 'adstock__Nano_pipe__saturation__a': 0.009691623781491833}. Best is trial 1 with value: 0.8364630759313576.
# [I 2024-03-11 17:17:54,007] Trial 2 finished with value: 0.8640153302118883 and parameters: {'adstock__tv_pipe__carryover__strength': 0.4301898855698616, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.004051048872696876, 'adstock__radio_pipe__carryover__strength': 0.1404038981461203, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.009554838356780235, 'adstock__Social_Media_pipe__carryover__strength': 0.6438567472191807, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.005346346140474575, 'adstock__Macro_pipe__carryover__strength': 0.188432092033039, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.006085930330700066, 'adstock__Micro_pipe__carryover__strength': 0.69846627060575, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.0014944200580302193, 'adstock__Nano_pipe__carryover__strength': 0.24357103792509316, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.0021502093650281797}. Best is trial 2 with value: 0.8640153302118883.
# [I 2024-03-11 17:17:54,273] Trial 3 finished with value: 0.5540960553901428 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7489259045868862, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.003709727763516032, 'adstock__radio_pipe__carryover__strength': 0.47356303881897854, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.0010760286304292578, 'adstock__Social_Media_pipe__carryover__strength': 0.29290258135684744, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.007429572443936331, 'adstock__Macro_pipe__carryover__strength': 0.8148703304241797, 'adstock__Macro_pipe__carryover__length': 2, 'adstock__Macro_pipe__saturation__a': 0.009141730950785402, 'adstock__Micro_pipe__carryover__strength': 0.38739827167860197, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.00964314123868665, 'adstock__Nano_pipe__carryover__strength': 0.2574388543353703, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.00019722489287016143}. Best is trial 2 with value: 0.8640153302118883.
# [I 2024-03-11 17:17:54,553] Trial 4 finished with value: 0.6950514245642312 and parameters: {'adstock__tv_pipe__carryover__strength': 0.8733858015336476, 'adstock__tv_pipe__carryover__length': 4, 'adstock__tv_pipe__saturation__a': 0.001975234627629391, 'adstock__radio_pipe__carryover__strength': 0.2780985813139495, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.008073428013011051, 'adstock__Social_Media_pipe__carryover__strength': 0.2534084975206714, 'adstock__Social_Media_pipe__carryover__length': 5, 'adstock__Social_Media_pipe__saturation__a': 0.0073119098779319235, 'adstock__Macro_pipe__carryover__strength': 0.2796392741466154, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.008660103149826624, 'adstock__Micro_pipe__carryover__strength': 0.6790897200507965, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.008401425901989777, 'adstock__Nano_pipe__carryover__strength': 0.7902412008221756, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.009017562136768102}. Best is trial 2 with value: 0.8640153302118883.
# [I 2024-03-11 17:17:54,906] Trial 5 finished with value: 0.8193596501441899 and parameters: {'adstock__tv_pipe__carryover__strength': 0.41242265702473146, 'adstock__tv_pipe__carryover__length': 5, 'adstock__tv_pipe__saturation__a': 0.009217745087066841, 'adstock__radio_pipe__carryover__strength': 0.8305556570483074, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.0014633792009631176, 'adstock__Social_Media_pipe__carryover__strength': 0.5870013545377906, 'adstock__Social_Media_pipe__carryover__length': 5, 'adstock__Social_Media_pipe__saturation__a': 0.008051978955128547, 'adstock__Macro_pipe__carryover__strength': 0.49806696515771665, 'adstock__Macro_pipe__carryover__length': 0, 'adstock__Macro_pipe__saturation__a': 0.0040964072617640365, 'adstock__Micro_pipe__carryover__strength': 0.5437061009520506, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.00209008228295398, 'adstock__Nano_pipe__carryover__strength': 0.6314474371589085, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.0006400799520133394}. Best is trial 2 with value: 0.8640153302118883.
# [I 2024-03-11 17:17:55,337] Trial 6 finished with value: 0.7374310599281456 and parameters: {'adstock__tv_pipe__carryover__strength': 0.5254913477433658, 'adstock__tv_pipe__carryover__length': 5, 'adstock__tv_pipe__saturation__a': 4.480942451490222e-05, 'adstock__radio_pipe__carryover__strength': 0.05023698828102108, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.00862834777611814, 'adstock__Social_Media_pipe__carryover__strength': 0.7661726753359349, 'adstock__Social_Media_pipe__carryover__length': 0, 'adstock__Social_Media_pipe__saturation__a': 0.008670036214812635, 'adstock__Macro_pipe__carryover__strength': 0.3072840915448757, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.008191287595982071, 'adstock__Micro_pipe__carryover__strength': 0.23079272261018335, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.007469020979879365, 'adstock__Nano_pipe__carryover__strength': 0.9248145111864309, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.0006645045314395381}. Best is trial 2 with value: 0.8640153302118883.
# [I 2024-03-11 17:17:55,660] Trial 7 finished with value: 0.8359921942011059 and parameters: {'adstock__tv_pipe__carryover__strength': 0.4068398861623914, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.007052775736794701, 'adstock__radio_pipe__carryover__strength': 0.4742902971576447, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.002642962238347322, 'adstock__Social_Media_pipe__carryover__strength': 0.5376549736727055, 'adstock__Social_Media_pipe__carryover__length': 5, 'adstock__Social_Media_pipe__saturation__a': 0.005472894992252935, 'adstock__Macro_pipe__carryover__strength': 0.8055793275193335, 'adstock__Macro_pipe__carryover__length': 2, 'adstock__Macro_pipe__saturation__a': 0.0009311946611777622, 'adstock__Micro_pipe__carryover__strength': 0.5681761228451423, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.004107689742551712, 'adstock__Nano_pipe__carryover__strength': 0.4402746930385596, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.0020404836001037207}. Best is trial 2 with value: 0.8640153302118883.
# [I 2024-03-11 17:17:55,951] Trial 8 finished with value: 0.9608831321703967 and parameters: {'adstock__tv_pipe__carryover__strength': 0.08400496198849106, 'adstock__tv_pipe__carryover__length': 6, 'adstock__tv_pipe__saturation__a': 0.0020000633410039315, 'adstock__radio_pipe__carryover__strength': 0.21092430731572687, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.0006152890504114883, 'adstock__Social_Media_pipe__carryover__strength': 0.5090822349645877, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.000923939667542919, 'adstock__Macro_pipe__carryover__strength': 0.3194411224190604, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.004850012392396932, 'adstock__Micro_pipe__carryover__strength': 0.19741635510773514, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.005282102567144773, 'adstock__Nano_pipe__carryover__strength': 0.6331687099334357, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.0016151130371984724}. Best is trial 8 with value: 0.9608831321703967.
# [I 2024-03-11 17:17:56,214] Trial 9 finished with value: 0.6044370053347332 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7423794135641802, 'adstock__tv_pipe__carryover__length': 6, 'adstock__tv_pipe__saturation__a': 0.001758934942195808, 'adstock__radio_pipe__carryover__strength': 0.4092746778401134, 'adstock__radio_pipe__carryover__length': 3, 'adstock__radio_pipe__saturation__a': 0.004402046511530907, 'adstock__Social_Media_pipe__carryover__strength': 0.6141790705115199, 'adstock__Social_Media_pipe__carryover__length': 5, 'adstock__Social_Media_pipe__saturation__a': 0.005045623859124973, 'adstock__Macro_pipe__carryover__strength': 0.6838205429909767, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.008573720343459261, 'adstock__Micro_pipe__carryover__strength': 0.10354683901127248, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.005906576318219149, 'adstock__Nano_pipe__carryover__strength': 0.13754843834512331, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.00850101111665877}. Best is trial 8 with value: 0.9608831321703967.
# [I 2024-03-11 17:17:56,523] Trial 10 finished with value: 0.985391204085896 and parameters: {'adstock__tv_pipe__carryover__strength': 0.0008726853952957803, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.005654856557423869, 'adstock__radio_pipe__carryover__strength': 0.6682142587374406, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.005980577416202885, 'adstock__Social_Media_pipe__carryover__strength': 0.0549758383350446, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.00013064140700119698, 'adstock__Macro_pipe__carryover__strength': 0.04145615567373234, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.0028690778550530915, 'adstock__Micro_pipe__carryover__strength': 0.9517967482657171, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.003889314650549356, 'adstock__Nano_pipe__carryover__strength': 0.5728604722291063, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.004705288114447561}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:56,808] Trial 11 finished with value: 0.9809700970048782 and parameters: {'adstock__tv_pipe__carryover__strength': 0.0599695714892859, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.006398941028455616, 'adstock__radio_pipe__carryover__strength': 0.6838480687736329, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.006260399412948388, 'adstock__Social_Media_pipe__carryover__strength': 0.9797842862511603, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 4.439119129542254e-05, 'adstock__Macro_pipe__carryover__strength': 0.03941221078097948, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.0026311786513061597, 'adstock__Micro_pipe__carryover__strength': 0.9886349196224021, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.0040352594321986495, 'adstock__Nano_pipe__carryover__strength': 0.5597369573397306, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.004312172216579779}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:57,086] Trial 12 finished with value: 0.9840693051136687 and parameters: {'adstock__tv_pipe__carryover__strength': 0.011095232447906856, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.006520717168005687, 'adstock__radio_pipe__carryover__strength': 0.6883360387355489, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.0063776048195933605, 'adstock__Social_Media_pipe__carryover__strength': 0.9758403307305847, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 2.2269107352462297e-05, 'adstock__Macro_pipe__carryover__strength': 0.04860234966708918, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.0026250289597304728, 'adstock__Micro_pipe__carryover__strength': 0.9971188504785922, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.0038370805207820634, 'adstock__Nano_pipe__carryover__strength': 0.4486919596215602, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.004323736477090788}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:57,386] Trial 13 finished with value: 0.9603372185607653 and parameters: {'adstock__tv_pipe__carryover__strength': 0.16806001162297368, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.006474711833823284, 'adstock__radio_pipe__carryover__strength': 0.676332701163743, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.00589468465647573, 'adstock__Social_Media_pipe__carryover__strength': 0.0853550692627233, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.0022371862739788075, 'adstock__Macro_pipe__carryover__strength': 0.006344165914704505, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.002820056366724165, 'adstock__Micro_pipe__carryover__strength': 0.9998703000865459, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.0029040164588692314, 'adstock__Nano_pipe__carryover__strength': 0.4141300936944929, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.00439953485242174}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:57,728] Trial 14 finished with value: 0.9831461754285842 and parameters: {'adstock__tv_pipe__carryover__strength': 0.24261546809899573, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.007501904419935142, 'adstock__radio_pipe__carryover__strength': 0.6695044145598306, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.004101220422337331, 'adstock__Social_Media_pipe__carryover__strength': 0.9837119053820322, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.002842098611943297, 'adstock__Macro_pipe__carryover__strength': 0.16531638047296143, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.0027463783510543248, 'adstock__Micro_pipe__carryover__strength': 0.8834719864817824, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.0032417903530476645, 'adstock__Nano_pipe__carryover__strength': 0.756124667657194, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.00569701366298323}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:57,983] Trial 15 finished with value: 0.9853426683662665 and parameters: {'adstock__tv_pipe__carryover__strength': 0.007430442021267206, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.0051839464418027585, 'adstock__radio_pipe__carryover__strength': 0.8010497080155426, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.006941537861140725, 'adstock__Social_Media_pipe__carryover__strength': 0.0013230053516238849, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.002601031318726837, 'adstock__Macro_pipe__carryover__strength': 0.529547534231669, 'adstock__Macro_pipe__carryover__length': 3, 'adstock__Macro_pipe__saturation__a': 8.719272638530069e-05, 'adstock__Micro_pipe__carryover__strength': 0.8192598297615006, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 9.835375091560034e-05, 'adstock__Nano_pipe__carryover__strength': 0.32466675091823327, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.0035873707305628345}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:58,198] Trial 16 finished with value: 0.9542504248979616 and parameters: {'adstock__tv_pipe__carryover__strength': 0.20520489595612978, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.004962252788014167, 'adstock__radio_pipe__carryover__strength': 0.8347081650428525, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.007463152551640309, 'adstock__Social_Media_pipe__carryover__strength': 0.05653911149034691, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.003031860285480844, 'adstock__Macro_pipe__carryover__strength': 0.4895506377905126, 'adstock__Macro_pipe__carryover__length': 3, 'adstock__Macro_pipe__saturation__a': 7.605311304228877e-05, 'adstock__Micro_pipe__carryover__strength': 0.8064702757531372, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.00013407413322832603, 'adstock__Nano_pipe__carryover__strength': 0.3063836644362137, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.003147874299610459}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:58,396] Trial 17 finished with value: 0.9281082966458843 and parameters: {'adstock__tv_pipe__carryover__strength': 0.2641695471570298, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.005281095983442382, 'adstock__radio_pipe__carryover__strength': 0.953775151268345, 'adstock__radio_pipe__carryover__length': 3, 'adstock__radio_pipe__saturation__a': 0.00350665515455337, 'adstock__Social_Media_pipe__carryover__strength': 0.3527003229163785, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.0015716292206409993, 'adstock__Macro_pipe__carryover__strength': 0.9455510884476932, 'adstock__Macro_pipe__carryover__length': 3, 'adstock__Macro_pipe__saturation__a': 0.0015931979195040827, 'adstock__Micro_pipe__carryover__strength': 0.8240911404322496, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.00040256374408527103, 'adstock__Nano_pipe__carryover__strength': 0.34001297290812116, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.007266736932742794}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:58,604] Trial 18 finished with value: 0.7277629413680111 and parameters: {'adstock__tv_pipe__carryover__strength': 0.5837170348487268, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.008113869679491197, 'adstock__radio_pipe__carryover__strength': 0.5778445596535333, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.005329692241021863, 'adstock__Social_Media_pipe__carryover__strength': 0.005083085547783776, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.0033637646371448672, 'adstock__Macro_pipe__carryover__strength': 0.426302278550164, 'adstock__Macro_pipe__carryover__length': 2, 'adstock__Macro_pipe__saturation__a': 0.006620116773384376, 'adstock__Micro_pipe__carryover__strength': 0.7048482860251342, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.006121839078394728, 'adstock__Nano_pipe__carryover__strength': 0.5743960194140654, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.003099472567613816}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:58,800] Trial 19 finished with value: 0.9752021328737687 and parameters: {'adstock__tv_pipe__carryover__strength': 0.11332997770346258, 'adstock__tv_pipe__carryover__length': 4, 'adstock__tv_pipe__saturation__a': 0.005163406767585088, 'adstock__radio_pipe__carryover__strength': 0.8025561880342936, 'adstock__radio_pipe__carryover__length': 3, 'adstock__radio_pipe__saturation__a': 0.007033517613126716, 'adstock__Social_Media_pipe__carryover__strength': 0.17177718216739937, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.0016387633083438187, 'adstock__Macro_pipe__carryover__strength': 0.6139882622601267, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.0015750993942013822, 'adstock__Micro_pipe__carryover__strength': 0.42731465472297836, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.0024193976188033395, 'adstock__Nano_pipe__carryover__strength': 0.7467625856890783, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.0053946311918654085}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:59,001] Trial 20 finished with value: 0.916087406284921 and parameters: {'adstock__tv_pipe__carryover__strength': 0.2989862498770696, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.00307708636899772, 'adstock__radio_pipe__carryover__strength': 0.568913081927961, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.00503931789226108, 'adstock__Social_Media_pipe__carryover__strength': 0.14462403717207645, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.004070801667879132, 'adstock__Macro_pipe__carryover__strength': 0.4272880892613724, 'adstock__Macro_pipe__carryover__length': 3, 'adstock__Macro_pipe__saturation__a': 0.0037346574214633657, 'adstock__Micro_pipe__carryover__strength': 0.859213307464976, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.0012821329546285323, 'adstock__Nano_pipe__carryover__strength': 0.9817484980465848, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.0033744308877296215}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:59,205] Trial 21 finished with value: 0.9849724868362596 and parameters: {'adstock__tv_pipe__carryover__strength': 0.0043161619446696435, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.005858823546224836, 'adstock__radio_pipe__carryover__strength': 0.7355125353450085, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.006392915293938504, 'adstock__Social_Media_pipe__carryover__strength': 0.8328363495764758, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.0001282988942520166, 'adstock__Macro_pipe__carryover__strength': 0.13285236670929662, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 4.0327161231300604e-05, 'adstock__Micro_pipe__carryover__strength': 0.9271161764145137, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.004225471832171846, 'adstock__Nano_pipe__carryover__strength': 0.4463093690991448, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.004347319194698949}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:59,408] Trial 22 finished with value: 0.983164108648434 and parameters: {'adstock__tv_pipe__carryover__strength': 0.04592607045057459, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.005687342590304969, 'adstock__radio_pipe__carryover__strength': 0.7722783238443308, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.007025699240409848, 'adstock__Social_Media_pipe__carryover__strength': 0.8257684882599319, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.0009389074078629693, 'adstock__Macro_pipe__carryover__strength': 0.14082228624988075, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.00013456440627281026, 'adstock__Micro_pipe__carryover__strength': 0.9087855237902478, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.004859189805788358, 'adstock__Nano_pipe__carryover__strength': 0.5074310388796937, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.006343062767629439}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:59,619] Trial 23 finished with value: 0.9846211846156203 and parameters: {'adstock__tv_pipe__carryover__strength': 0.0019265616103532153, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.004457224526306385, 'adstock__radio_pipe__carryover__strength': 0.9993668773597955, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.008479895622003995, 'adstock__Social_Media_pipe__carryover__strength': 0.7302113504583754, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.0009276701196728012, 'adstock__Macro_pipe__carryover__strength': 0.24064060709988247, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0016915584255807912, 'adstock__Micro_pipe__carryover__strength': 0.7648050936210924, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.005022943714504365, 'adstock__Nano_pipe__carryover__strength': 0.1884192918463563, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.004832146140065661}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:17:59,816] Trial 24 finished with value: 0.9824077584411859 and parameters: {'adstock__tv_pipe__carryover__strength': 0.1547764502053914, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.007844767373014955, 'adstock__radio_pipe__carryover__strength': 0.8967643434416853, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.0056808019251898935, 'adstock__Social_Media_pipe__carryover__strength': 0.4336568087052384, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.004072226388408704, 'adstock__Macro_pipe__carryover__strength': 0.09119577270254928, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.000833832222362325, 'adstock__Micro_pipe__carryover__strength': 0.6167643179363009, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.00647469670035296, 'adstock__Nano_pipe__carryover__strength': 0.37280118025915715, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.0038513071511213836}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:00,045] Trial 25 finished with value: 0.9674509311753722 and parameters: {'adstock__tv_pipe__carryover__strength': 0.13909611515675427, 'adstock__tv_pipe__carryover__length': 4, 'adstock__tv_pipe__saturation__a': 0.005858144576691676, 'adstock__radio_pipe__carryover__strength': 0.5875824859967782, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.007552553990504924, 'adstock__Social_Media_pipe__carryover__strength': 0.4198257000115233, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.0019063575202617389, 'adstock__Macro_pipe__carryover__strength': 0.383441087729461, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0020886205029467045, 'adstock__Micro_pipe__carryover__strength': 0.9101343712945779, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.0032057103322881953, 'adstock__Nano_pipe__carryover__strength': 0.5125207656399119, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.002608290661036992}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:00,404] Trial 26 finished with value: 0.9805263045363365 and parameters: {'adstock__tv_pipe__carryover__strength': 0.0015756188071499944, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.0030629517943086995, 'adstock__radio_pipe__carryover__strength': 0.7198536999940943, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.006740268854794708, 'adstock__Social_Media_pipe__carryover__strength': 0.019918713201161058, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.0005827190155303244, 'adstock__Macro_pipe__carryover__strength': 0.5667320172601263, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 8.351761277014065e-05, 'adstock__Micro_pipe__carryover__strength': 0.7737384370776428, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.0044363899551029375, 'adstock__Nano_pipe__carryover__strength': 0.6267880486412925, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.007530439163055892}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:00,633] Trial 27 finished with value: 0.5159908589542742 and parameters: {'adstock__tv_pipe__carryover__strength': 0.9928288352055712, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.004467133206126512, 'adstock__radio_pipe__carryover__strength': 0.7546383628621836, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.00456969165652763, 'adstock__Social_Media_pipe__carryover__strength': 0.8377814113912048, 'adstock__Social_Media_pipe__carryover__length': 0, 'adstock__Social_Media_pipe__saturation__a': 0.002360786016400916, 'adstock__Macro_pipe__carryover__strength': 0.1180366622484173, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.0038159798368780982, 'adstock__Micro_pipe__carryover__strength': 0.9334184330116619, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.0007128787314397724, 'adstock__Nano_pipe__carryover__strength': 0.6886374825942909, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.005331654722887923}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:00,828] Trial 28 finished with value: 0.9011202150674249 and parameters: {'adstock__tv_pipe__carryover__strength': 0.3107840155514168, 'adstock__tv_pipe__carryover__length': 5, 'adstock__tv_pipe__saturation__a': 0.00840309355974655, 'adstock__radio_pipe__carryover__strength': 0.34458602865043364, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.003535666928823143, 'adstock__Social_Media_pipe__carryover__strength': 0.25613307682424546, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.0041577177563497545, 'adstock__Macro_pipe__carryover__strength': 0.23845631802054024, 'adstock__Macro_pipe__carryover__length': 3, 'adstock__Macro_pipe__saturation__a': 0.0010190168504898005, 'adstock__Micro_pipe__carryover__strength': 0.7511299392605633, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.0025373805115863983, 'adstock__Nano_pipe__carryover__strength': 0.29157036367350486, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.006102577889461409}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:01,030] Trial 29 finished with value: 0.9676222357646804 and parameters: {'adstock__tv_pipe__carryover__strength': 0.10568432193832931, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.009596663522875895, 'adstock__radio_pipe__carryover__strength': 0.6177919175575438, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.009680680803541793, 'adstock__Social_Media_pipe__carryover__strength': 0.10510866487938082, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.001235280315889445, 'adstock__Macro_pipe__carryover__strength': 0.35796737708828497, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.005586842093212906, 'adstock__Micro_pipe__carryover__strength': 0.6213101925679311, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.00158988435827096, 'adstock__Nano_pipe__carryover__strength': 0.1665637961013076, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.00723023963115327}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:01,236] Trial 30 finished with value: 0.6249368082431228 and parameters: {'adstock__tv_pipe__carryover__strength': 0.6224884519506775, 'adstock__tv_pipe__carryover__length': 4, 'adstock__tv_pipe__saturation__a': 0.005736610845570712, 'adstock__radio_pipe__carryover__strength': 0.867227864089751, 'adstock__radio_pipe__carryover__length': 3, 'adstock__radio_pipe__saturation__a': 0.007913897776877137, 'adstock__Social_Media_pipe__carryover__strength': 0.2361424622246977, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.005942301855617918, 'adstock__Macro_pipe__carryover__strength': 0.20476218575747052, 'adstock__Macro_pipe__carryover__length': 2, 'adstock__Macro_pipe__saturation__a': 0.003410136950019932, 'adstock__Micro_pipe__carryover__strength': 0.9335622661047176, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.0036395189209819916, 'adstock__Nano_pipe__carryover__strength': 0.028720029285273507, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.003858488936337463}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:01,465] Trial 31 finished with value: 0.9846740358359636 and parameters: {'adstock__tv_pipe__carryover__strength': 0.0023125009285317596, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.004592850883375724, 'adstock__radio_pipe__carryover__strength': 0.9927731717825055, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.008884329431049444, 'adstock__Social_Media_pipe__carryover__strength': 0.7372993351059809, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.0005689914013685879, 'adstock__Macro_pipe__carryover__strength': 0.07568422289547444, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.001777291812468325, 'adstock__Micro_pipe__carryover__strength': 0.8291734155668018, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.0051505140366653514, 'adstock__Nano_pipe__carryover__strength': 0.1750008777615198, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.004788412712638978}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:01,684] Trial 32 finished with value: 0.9778633101665886 and parameters: {'adstock__tv_pipe__carryover__strength': 0.0621131605182083, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.0034265546898608677, 'adstock__radio_pipe__carryover__strength': 0.9571611437700747, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.009147126819542576, 'adstock__Social_Media_pipe__carryover__strength': 0.8954471057333596, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.00047930302645468056, 'adstock__Macro_pipe__carryover__strength': 0.07715141178734675, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0005918353347428236, 'adstock__Micro_pipe__carryover__strength': 0.8251867206418205, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.006964529716604538, 'adstock__Nano_pipe__carryover__strength': 0.37623751890506596, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.004734418218499799}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:01,885] Trial 33 finished with value: 0.955075728104498 and parameters: {'adstock__tv_pipe__carryover__strength': 0.19743577999693057, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.004538677528420241, 'adstock__radio_pipe__carryover__strength': 0.8849862016801517, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.008987294129879718, 'adstock__Social_Media_pipe__carryover__strength': 0.7119481581003131, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 6.978812167981834e-05, 'adstock__Macro_pipe__carryover__strength': 0.6054441429583152, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0020981723582119663, 'adstock__Micro_pipe__carryover__strength': 0.8505729769263863, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.005864173380514289, 'adstock__Nano_pipe__carryover__strength': 0.11934938890401756, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.0038330039948803215}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:02,103] Trial 34 finished with value: 0.9723006204283896 and parameters: {'adstock__tv_pipe__carryover__strength': 0.10980361615525705, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.0069192419576539705, 'adstock__radio_pipe__carryover__strength': 0.7658880179298093, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.005929053224219783, 'adstock__Social_Media_pipe__carryover__strength': 0.6801074556150004, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.0023674861660408332, 'adstock__Macro_pipe__carryover__strength': 0.13505050893755766, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.001283050512428815, 'adstock__Micro_pipe__carryover__strength': 0.7171408346398827, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.007903531620867443, 'adstock__Nano_pipe__carryover__strength': 0.21829635847193518, 'adstock__Nano_pipe__carryover__length': 0, 'adstock__Nano_pipe__saturation__a': 0.005666057114717219}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:02,297] Trial 35 finished with value: 0.9814311524250426 and parameters: {'adstock__tv_pipe__carryover__strength': 0.05789091426256687, 'adstock__tv_pipe__carryover__length': 4, 'adstock__tv_pipe__saturation__a': 0.005872775542800413, 'adstock__radio_pipe__carryover__strength': 0.5360672081831415, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.006609283844497063, 'adstock__Social_Media_pipe__carryover__strength': 0.8960517406498173, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.001290554260030067, 'adstock__Macro_pipe__carryover__strength': 0.028005492610136296, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0005913492336137053, 'adstock__Micro_pipe__carryover__strength': 0.9428388767769594, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.005330385375373151, 'adstock__Nano_pipe__carryover__strength': 0.08224962788177881, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.002377952189156894}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:02,514] Trial 36 finished with value: 0.9426744986355882 and parameters: {'adstock__tv_pipe__carryover__strength': 0.23314301459135858, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.004021395592580323, 'adstock__radio_pipe__carryover__strength': 0.9878393584902585, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.00760370610244413, 'adstock__Social_Media_pipe__carryover__strength': 0.7825976247170778, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.00039647875046664577, 'adstock__Macro_pipe__carryover__strength': 0.20195760834913695, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.0019942948557019912, 'adstock__Micro_pipe__carryover__strength': 0.34161477976631843, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.00934980808551663, 'adstock__Nano_pipe__carryover__strength': 0.46032537677972574, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.006688200600855501}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:02,733] Trial 37 finished with value: 0.8777648814881713 and parameters: {'adstock__tv_pipe__carryover__strength': 0.35027042966023375, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.005002134493000155, 'adstock__radio_pipe__carryover__strength': 0.9135991363152727, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.008164015443055584, 'adstock__Social_Media_pipe__carryover__strength': 0.3407525669346297, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.00993014334531342, 'adstock__Macro_pipe__carryover__strength': 0.5434401435404217, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.007313590505920351, 'adstock__Micro_pipe__carryover__strength': 0.6752835314801588, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.0019132743175042867, 'adstock__Nano_pipe__carryover__strength': 0.24540945960980332, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.005064874605052779}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:02,959] Trial 38 finished with value: 0.9593638519915018 and parameters: {'adstock__tv_pipe__carryover__strength': 0.16163316141995165, 'adstock__tv_pipe__carryover__length': 4, 'adstock__tv_pipe__saturation__a': 0.0035676685924258614, 'adstock__radio_pipe__carryover__strength': 0.6322200457787726, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.009857218058950056, 'adstock__Social_Media_pipe__carryover__strength': 0.5602407759059879, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.0018814629771303165, 'adstock__Macro_pipe__carryover__strength': 0.7228059354070672, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.004873516864123066, 'adstock__Micro_pipe__carryover__strength': 0.7873369537658539, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.004498361716953288, 'adstock__Nano_pipe__carryover__strength': 0.2940125653009616, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.0017035526452305056}. Best is trial 10 with value: 0.985391204085896.
# [I 2024-03-11 17:18:03,165] Trial 39 finished with value: 0.8006771601765388 and parameters: {'adstock__tv_pipe__carryover__strength': 0.47273440022195123, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.007320308724695548, 'adstock__radio_pipe__carryover__strength': 0.7361734351235872, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.005415283223697973, 'adstock__Social_Media_pipe__carryover__strength': 0.6503396130400176, 'adstock__Social_Media_pipe__carryover__length': 5, 'adstock__Social_Media_pipe__saturation__a': 0.0034334416771235558, 'adstock__Macro_pipe__carryover__strength': 0.8987132422451065, 'adstock__Macro_pipe__carryover__length': 3, 'adstock__Macro_pipe__saturation__a': 0.004402391923904918, 'adstock__Micro_pipe__carryover__strength': 0.6321012040871301, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.0010016650132661483, 'adstock__Nano_pipe__carryover__strength': 0.007367057877838673, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.0027232193445265278}. Best is trial 10 with value: 0.985391204085896.
# ...
# [I 2024-03-11 17:20:38,962] Trial 87 finished with value: 0.7853522946562334 and parameters: {'adstock__tv_pipe__carryover__strength': 0.6679417906359684, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.00042459677973066324, 'adstock__radio_pipe__carryover__strength': 0.8464030159935828, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.004072628776272595, 'adstock__Social_Media_pipe__carryover__strength': 0.4279769706638009, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.009322334891844248, 'adstock__Macro_pipe__carryover__strength': 0.8629273884454599, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.007711447229474691, 'adstock__Micro_pipe__carryover__strength': 0.543123179600814, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.008218841266752798, 'adstock__Nano_pipe__carryover__strength': 0.053731448662375, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.0020898798561392795}. Best is trial 84 with value: 0.8622009632962546.
# [I 2024-03-11 17:20:39,251] Trial 88 finished with value: 0.8604939597085426 and parameters: {'adstock__tv_pipe__carryover__strength': 0.6352116236101233, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.001923627130782557, 'adstock__radio_pipe__carryover__strength': 0.9246925069647738, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.005603655849367005, 'adstock__Social_Media_pipe__carryover__strength': 0.3054586239030788, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.009947125548938703, 'adstock__Macro_pipe__carryover__strength': 0.8288957259471444, 'adstock__Macro_pipe__carryover__length': 3, 'adstock__Macro_pipe__saturation__a': 0.00880248140024761, 'adstock__Micro_pipe__carryover__strength': 0.4489409697025666, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.008675258942630997, 'adstock__Nano_pipe__carryover__strength': 0.25487776285982117, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.0015593850932776759}. Best is trial 84 with value: 0.8622009632962546.
# [I 2024-03-11 17:20:39,558] Trial 89 finished with value: 0.861942718649372 and parameters: {'adstock__tv_pipe__carryover__strength': 0.748200662778687, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0015279368033106388, 'adstock__radio_pipe__carryover__strength': 0.730082741492557, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.0065495334862699225, 'adstock__Social_Media_pipe__carryover__strength': 0.13528489917122294, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.008736322092011924, 'adstock__Macro_pipe__carryover__strength': 0.9430886381338552, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.009601740732047078, 'adstock__Micro_pipe__carryover__strength': 0.47085367116644894, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.00909358427160654, 'adstock__Nano_pipe__carryover__strength': 0.31714175839239334, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.002191450006173699}. Best is trial 84 with value: 0.8622009632962546.
# [I 2024-03-11 17:20:39,845] Trial 90 finished with value: 0.5714619903726698 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7513061340815197, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.0014296984207466121, 'adstock__radio_pipe__carryover__strength': 0.6598059419389397, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.006626941137164423, 'adstock__Social_Media_pipe__carryover__strength': 0.04141032892245497, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.008806485949933468, 'adstock__Macro_pipe__carryover__strength': 0.9333711669494623, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.007419750363372458, 'adstock__Micro_pipe__carryover__strength': 0.41348870640662505, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.009142399549636759, 'adstock__Nano_pipe__carryover__strength': 0.32236717020369154, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.003228813688292601}. Best is trial 84 with value: 0.8622009632962546.
# [I 2024-03-11 17:20:40,128] Trial 91 finished with value: 0.8597052656770987 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7727667061744901, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0009451341163490089, 'adstock__radio_pipe__carryover__strength': 0.7659050722328279, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.007275410189739124, 'adstock__Social_Media_pipe__carryover__strength': 0.4741799971316807, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.008342857267424992, 'adstock__Macro_pipe__carryover__strength': 0.9696351602537577, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.009699307573178686, 'adstock__Micro_pipe__carryover__strength': 0.4650761320184764, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.007643369344895641, 'adstock__Nano_pipe__carryover__strength': 0.18643999078434467, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.002205666782982978}. Best is trial 84 with value: 0.8622009632962546.
# [I 2024-03-11 17:20:40,437] Trial 92 finished with value: 0.8621312791083529 and parameters: {'adstock__tv_pipe__carryover__strength': 0.8058173959167554, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0014963717250761894, 'adstock__radio_pipe__carryover__strength': 0.7340451489250949, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.0054183100871498914, 'adstock__Social_Media_pipe__carryover__strength': 0.1477049097962802, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.00925708429916734, 'adstock__Macro_pipe__carryover__strength': 0.9113890617032183, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.009954905509478787, 'adstock__Micro_pipe__carryover__strength': 0.5790543086333615, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.008586850149532898, 'adstock__Nano_pipe__carryover__strength': 0.2238646221595308, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.0014717976260033524}. Best is trial 84 with value: 0.8622009632962546.
# [I 2024-03-11 17:20:40,730] Trial 93 finished with value: 0.8624961562809867 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7986440762725391, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0013315200140216312, 'adstock__radio_pipe__carryover__strength': 0.7291552737232041, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.005422335768788948, 'adstock__Social_Media_pipe__carryover__strength': 0.1412785752849044, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.009603777296749286, 'adstock__Macro_pipe__carryover__strength': 0.8990739458753523, 'adstock__Macro_pipe__carryover__length': 0, 'adstock__Macro_pipe__saturation__a': 0.009930477060043429, 'adstock__Micro_pipe__carryover__strength': 0.63324731030896, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.008919243430203191, 'adstock__Nano_pipe__carryover__strength': 0.27121116298758713, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.001417141560848307}. Best is trial 93 with value: 0.8624961562809867.
# [I 2024-03-11 17:20:41,015] Trial 94 finished with value: 0.8477055698870938 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7285387705528737, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0006969577610609422, 'adstock__radio_pipe__carryover__strength': 0.7252008913655719, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.005354100262845, 'adstock__Social_Media_pipe__carryover__strength': 0.1543077701585461, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.00956922351754752, 'adstock__Macro_pipe__carryover__strength': 0.9520790510216773, 'adstock__Macro_pipe__carryover__length': 2, 'adstock__Macro_pipe__saturation__a': 0.009853550065625627, 'adstock__Micro_pipe__carryover__strength': 0.6389889391276, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.008924219713378579, 'adstock__Nano_pipe__carryover__strength': 0.27378323165227847, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.0014853704442626978}. Best is trial 93 with value: 0.8624961562809867.
# [I 2024-03-11 17:20:41,310] Trial 95 finished with value: 0.4497131960276137 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7963142949751907, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.001138014135315416, 'adstock__radio_pipe__carryover__strength': 0.6905550654527677, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.006904821414160349, 'adstock__Social_Media_pipe__carryover__strength': 0.1464903468968715, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.009276201423782271, 'adstock__Macro_pipe__carryover__strength': 0.9172323697799613, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.009990653737711382, 'adstock__Micro_pipe__carryover__strength': 0.5765303408032055, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.009999209559310161, 'adstock__Nano_pipe__carryover__strength': 0.37267557015881536, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.00267625865289514}. Best is trial 93 with value: 0.8624961562809867.
# [I 2024-03-11 17:20:41,623] Trial 96 finished with value: 0.8610055399248473 and parameters: {'adstock__tv_pipe__carryover__strength': 0.753391172038391, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.001908608324670089, 'adstock__radio_pipe__carryover__strength': 0.7761722361001682, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.004801650803360156, 'adstock__Social_Media_pipe__carryover__strength': 0.22748116558827414, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.009009957532884394, 'adstock__Macro_pipe__carryover__strength': 0.9847793091508543, 'adstock__Macro_pipe__carryover__length': 0, 'adstock__Macro_pipe__saturation__a': 0.009553088979718082, 'adstock__Micro_pipe__carryover__strength': 0.5393821234626885, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.008576366589339551, 'adstock__Nano_pipe__carryover__strength': 0.2586643418966714, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.0019315857381233198}. Best is trial 93 with value: 0.8624961562809867.
# [I 2024-03-11 17:20:41,905] Trial 97 finished with value: 0.860492519855265 and parameters: {'adstock__tv_pipe__carryover__strength': 0.6946536484299837, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0020649930567170974, 'adstock__radio_pipe__carryover__strength': 0.8180034798276521, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.004708642687517005, 'adstock__Social_Media_pipe__carryover__strength': 0.23320408444204238, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.009705997038023193, 'adstock__Macro_pipe__carryover__strength': 0.9840445979632372, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.009582850179928326, 'adstock__Micro_pipe__carryover__strength': 0.5441122656115595, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.00857502806494764, 'adstock__Nano_pipe__carryover__strength': 0.31763462611911475, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.001967432095577281}. Best is trial 93 with value: 0.8624961562809867.
# [I 2024-03-11 17:20:42,192] Trial 98 finished with value: 0.8609382524151471 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7520394271257301, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0018526338209668518, 'adstock__radio_pipe__carryover__strength': 0.7753746621966358, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.005042573029623568, 'adstock__Social_Media_pipe__carryover__strength': 0.10495256937633976, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.009178969067054916, 'adstock__Macro_pipe__carryover__strength': 0.9488773959709009, 'adstock__Macro_pipe__carryover__length': 0, 'adstock__Macro_pipe__saturation__a': 0.00931065809447829, 'adstock__Micro_pipe__carryover__strength': 0.6418213113839523, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.003482157717143882, 'adstock__Nano_pipe__carryover__strength': 0.2570031786733526, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.002307216948653356}. Best is trial 93 with value: 0.8624961562809867.
# [I 2024-03-11 17:20:42,504] Trial 99 finished with value: 0.5967421858814909 and parameters: {'adstock__tv_pipe__carryover__strength': 0.6599343606915318, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.002227026147474342, 'adstock__radio_pipe__carryover__strength': 0.7700982438310396, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.0042568317893876655, 'adstock__Social_Media_pipe__carryover__strength': 0.07608022393182574, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.00921094932568951, 'adstock__Macro_pipe__carryover__strength': 0.9983231238801423, 'adstock__Macro_pipe__carryover__length': 2, 'adstock__Macro_pipe__saturation__a': 0.00938583354654859, 'adstock__Micro_pipe__carryover__strength': 0.5790342529738, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.0032449577531844355, 'adstock__Nano_pipe__carryover__strength': 0.25284504312306777, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.0021163814404437198}. Best is trial 93 with value: 0.8624961562809867.
# 0.8619274966034197

# %% [markdown]
# 0.86

# %%
# Fitting X and y variable on the new Tuned Model
tuned_model.fit(X2, y2)
# Out:
# [I 2024-03-11 17:20:42,619] A new study created in memory with name: no-name-5c604c01-13ae-467a-bfc6-daf403fea032
# [I 2024-03-11 17:20:42,886] Trial 0 finished with value: 0.7172022891158132 and parameters: {'adstock__tv_pipe__carryover__strength': 0.4860473230215504, 'adstock__tv_pipe__carryover__length': 4, 'adstock__tv_pipe__saturation__a': 0.009855760506615989, 'adstock__radio_pipe__carryover__strength': 0.1955964101622225, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.00980582177099305, 'adstock__Social_Media_pipe__carryover__strength': 0.18048029738995275, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.008463095456331128, 'adstock__Macro_pipe__carryover__strength': 0.7967092952533198, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.00517502161880338, 'adstock__Micro_pipe__carryover__strength': 0.04182737713424278, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.0014206610097397077, 'adstock__Nano_pipe__carryover__strength': 0.07832671372998268, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.006592437999535571}. Best is trial 0 with value: 0.7172022891158132.
# [I 2024-03-11 17:20:43,150] Trial 1 finished with value: 0.7300171030129317 and parameters: {'adstock__tv_pipe__carryover__strength': 0.35725476168521175, 'adstock__tv_pipe__carryover__length': 6, 'adstock__tv_pipe__saturation__a': 0.001651149068523966, 'adstock__radio_pipe__carryover__strength': 0.9192135617465139, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.0017677763778372825, 'adstock__Social_Media_pipe__carryover__strength': 0.5057684183863022, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.009897365793712223, 'adstock__Macro_pipe__carryover__strength': 0.6947000513172431, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0008235858666189444, 'adstock__Micro_pipe__carryover__strength': 0.25690484812921544, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.007316067473600314, 'adstock__Nano_pipe__carryover__strength': 0.06991967936105048, 'adstock__Nano_pipe__carryover__length': 0, 'adstock__Nano_pipe__saturation__a': 0.009691623781491833}. Best is trial 1 with value: 0.7300171030129317.
# [I 2024-03-11 17:20:43,406] Trial 2 finished with value: 0.7562827003500885 and parameters: {'adstock__tv_pipe__carryover__strength': 0.4301898855698616, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.004051048872696876, 'adstock__radio_pipe__carryover__strength': 0.1404038981461203, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.009554838356780235, 'adstock__Social_Media_pipe__carryover__strength': 0.6438567472191807, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.005346346140474575, 'adstock__Macro_pipe__carryover__strength': 0.188432092033039, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.006085930330700066, 'adstock__Micro_pipe__carryover__strength': 0.69846627060575, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.0014944200580302193, 'adstock__Nano_pipe__carryover__strength': 0.24357103792509316, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.0021502093650281797}. Best is trial 2 with value: 0.7562827003500885.
# [I 2024-03-11 17:20:43,696] Trial 3 finished with value: 0.5318662423645019 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7489259045868862, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.003709727763516032, 'adstock__radio_pipe__carryover__strength': 0.47356303881897854, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.0010760286304292578, 'adstock__Social_Media_pipe__carryover__strength': 0.29290258135684744, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.007429572443936331, 'adstock__Macro_pipe__carryover__strength': 0.8148703304241797, 'adstock__Macro_pipe__carryover__length': 2, 'adstock__Macro_pipe__saturation__a': 0.009141730950785402, 'adstock__Micro_pipe__carryover__strength': 0.38739827167860197, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.00964314123868665, 'adstock__Nano_pipe__carryover__strength': 0.2574388543353703, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.00019722489287016143}. Best is trial 2 with value: 0.7562827003500885.
# [I 2024-03-11 17:20:43,956] Trial 4 finished with value: 0.6492392467307535 and parameters: {'adstock__tv_pipe__carryover__strength': 0.8733858015336476, 'adstock__tv_pipe__carryover__length': 4, 'adstock__tv_pipe__saturation__a': 0.001975234627629391, 'adstock__radio_pipe__carryover__strength': 0.2780985813139495, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.008073428013011051, 'adstock__Social_Media_pipe__carryover__strength': 0.2534084975206714, 'adstock__Social_Media_pipe__carryover__length': 5, 'adstock__Social_Media_pipe__saturation__a': 0.0073119098779319235, 'adstock__Macro_pipe__carryover__strength': 0.2796392741466154, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.008660103149826624, 'adstock__Micro_pipe__carryover__strength': 0.6790897200507965, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.008401425901989777, 'adstock__Nano_pipe__carryover__strength': 0.7902412008221756, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.009017562136768102}. Best is trial 2 with value: 0.7562827003500885.
# [I 2024-03-11 17:20:44,222] Trial 5 finished with value: 0.7504026362290048 and parameters: {'adstock__tv_pipe__carryover__strength': 0.41242265702473146, 'adstock__tv_pipe__carryover__length': 5, 'adstock__tv_pipe__saturation__a': 0.009217745087066841, 'adstock__radio_pipe__carryover__strength': 0.8305556570483074, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.0014633792009631176, 'adstock__Social_Media_pipe__carryover__strength': 0.5870013545377906, 'adstock__Social_Media_pipe__carryover__length': 5, 'adstock__Social_Media_pipe__saturation__a': 0.008051978955128547, 'adstock__Macro_pipe__carryover__strength': 0.49806696515771665, 'adstock__Macro_pipe__carryover__length': 0, 'adstock__Macro_pipe__saturation__a': 0.0040964072617640365, 'adstock__Micro_pipe__carryover__strength': 0.5437061009520506, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.00209008228295398, 'adstock__Nano_pipe__carryover__strength': 0.6314474371589085, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.0006400799520133394}. Best is trial 2 with value: 0.7562827003500885.
# [I 2024-03-11 17:20:44,647] Trial 6 finished with value: 0.6944230521604193 and parameters: {'adstock__tv_pipe__carryover__strength': 0.5254913477433658, 'adstock__tv_pipe__carryover__length': 5, 'adstock__tv_pipe__saturation__a': 4.480942451490222e-05, 'adstock__radio_pipe__carryover__strength': 0.05023698828102108, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.00862834777611814, 'adstock__Social_Media_pipe__carryover__strength': 0.7661726753359349, 'adstock__Social_Media_pipe__carryover__length': 0, 'adstock__Social_Media_pipe__saturation__a': 0.008670036214812635, 'adstock__Macro_pipe__carryover__strength': 0.3072840915448757, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.008191287595982071, 'adstock__Micro_pipe__carryover__strength': 0.23079272261018335, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.007469020979879365, 'adstock__Nano_pipe__carryover__strength': 0.9248145111864309, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.0006645045314395381}. Best is trial 2 with value: 0.7562827003500885.
# [I 2024-03-11 17:20:44,992] Trial 7 finished with value: 0.7088914975029961 and parameters: {'adstock__tv_pipe__carryover__strength': 0.4068398861623914, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.007052775736794701, 'adstock__radio_pipe__carryover__strength': 0.4742902971576447, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.002642962238347322, 'adstock__Social_Media_pipe__carryover__strength': 0.5376549736727055, 'adstock__Social_Media_pipe__carryover__length': 5, 'adstock__Social_Media_pipe__saturation__a': 0.005472894992252935, 'adstock__Macro_pipe__carryover__strength': 0.8055793275193335, 'adstock__Macro_pipe__carryover__length': 2, 'adstock__Macro_pipe__saturation__a': 0.0009311946611777622, 'adstock__Micro_pipe__carryover__strength': 0.5681761228451423, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.004107689742551712, 'adstock__Nano_pipe__carryover__strength': 0.4402746930385596, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.0020404836001037207}. Best is trial 2 with value: 0.7562827003500885.
# [I 2024-03-11 17:20:45,472] Trial 8 finished with value: 0.8481500071323114 and parameters: {'adstock__tv_pipe__carryover__strength': 0.08400496198849106, 'adstock__tv_pipe__carryover__length': 6, 'adstock__tv_pipe__saturation__a': 0.0020000633410039315, 'adstock__radio_pipe__carryover__strength': 0.21092430731572687, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.0006152890504114883, 'adstock__Social_Media_pipe__carryover__strength': 0.5090822349645877, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.000923939667542919, 'adstock__Macro_pipe__carryover__strength': 0.3194411224190604, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.004850012392396932, 'adstock__Micro_pipe__carryover__strength': 0.19741635510773514, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.005282102567144773, 'adstock__Nano_pipe__carryover__strength': 0.6331687099334357, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.0016151130371984724}. Best is trial 8 with value: 0.8481500071323114.
# [I 2024-03-11 17:20:45,881] Trial 9 finished with value: 0.5796117002044393 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7423794135641802, 'adstock__tv_pipe__carryover__length': 6, 'adstock__tv_pipe__saturation__a': 0.001758934942195808, 'adstock__radio_pipe__carryover__strength': 0.4092746778401134, 'adstock__radio_pipe__carryover__length': 3, 'adstock__radio_pipe__saturation__a': 0.004402046511530907, 'adstock__Social_Media_pipe__carryover__strength': 0.6141790705115199, 'adstock__Social_Media_pipe__carryover__length': 5, 'adstock__Social_Media_pipe__saturation__a': 0.005045623859124973, 'adstock__Macro_pipe__carryover__strength': 0.6838205429909767, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.008573720343459261, 'adstock__Micro_pipe__carryover__strength': 0.10354683901127248, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.005906576318219149, 'adstock__Nano_pipe__carryover__strength': 0.13754843834512331, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.00850101111665877}. Best is trial 8 with value: 0.8481500071323114.
# [I 2024-03-11 17:20:46,367] Trial 10 finished with value: 0.8535627079082682 and parameters: {'adstock__tv_pipe__carryover__strength': 0.0008726853952957803, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.005654856557423869, 'adstock__radio_pipe__carryover__strength': 0.6682142587374406, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.005980577416202885, 'adstock__Social_Media_pipe__carryover__strength': 0.0549758383350446, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.00013064140700119698, 'adstock__Macro_pipe__carryover__strength': 0.04145615567373234, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.0028690778550530915, 'adstock__Micro_pipe__carryover__strength': 0.9517967482657171, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.003889314650549356, 'adstock__Nano_pipe__carryover__strength': 0.5728604722291063, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.004705288114447561}. Best is trial 10 with value: 0.8535627079082682.
# [I 2024-03-11 17:20:46,749] Trial 11 finished with value: 0.8498989308302299 and parameters: {'adstock__tv_pipe__carryover__strength': 0.0599695714892859, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.006398941028455616, 'adstock__radio_pipe__carryover__strength': 0.6838480687736329, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.006260399412948388, 'adstock__Social_Media_pipe__carryover__strength': 0.9797842862511603, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 4.439119129542254e-05, 'adstock__Macro_pipe__carryover__strength': 0.03941221078097948, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.0026311786513061597, 'adstock__Micro_pipe__carryover__strength': 0.9886349196224021, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.0040352594321986495, 'adstock__Nano_pipe__carryover__strength': 0.5597369573397306, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.004312172216579779}. Best is trial 10 with value: 0.8535627079082682.
# [I 2024-03-11 17:20:47,140] Trial 12 finished with value: 0.84926031428048 and parameters: {'adstock__tv_pipe__carryover__strength': 0.011095232447906856, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.006520717168005687, 'adstock__radio_pipe__carryover__strength': 0.6883360387355489, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.0063776048195933605, 'adstock__Social_Media_pipe__carryover__strength': 0.9758403307305847, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 2.2269107352462297e-05, 'adstock__Macro_pipe__carryover__strength': 0.04860234966708918, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.0026250289597304728, 'adstock__Micro_pipe__carryover__strength': 0.9971188504785922, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.0038370805207820634, 'adstock__Nano_pipe__carryover__strength': 0.4486919596215602, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.004323736477090788}. Best is trial 10 with value: 0.8535627079082682.
# [I 2024-03-11 17:20:47,769] Trial 13 finished with value: 0.8351267621714943 and parameters: {'adstock__tv_pipe__carryover__strength': 0.16806001162297368, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.006432596390261504, 'adstock__radio_pipe__carryover__strength': 0.6729887037074036, 'adstock__radio_pipe__carryover__length': 0, 'adstock__radio_pipe__saturation__a': 0.00589468465647573, 'adstock__Social_Media_pipe__carryover__strength': 0.0853550692627233, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.0022371862739788075, 'adstock__Macro_pipe__carryover__strength': 0.010556495416445467, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.002820056366724165, 'adstock__Micro_pipe__carryover__strength': 0.9998666952694227, 'adstock__Micro_pipe__carryover__length': 0, 'adstock__Micro_pipe__saturation__a': 0.0029040164588692314, 'adstock__Nano_pipe__carryover__strength': 0.6059037518111966, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.00439953485242174}. Best is trial 10 with value: 0.8535627079082682.
# [I 2024-03-11 17:20:48,336] Trial 14 finished with value: 0.8585790137417068 and parameters: {'adstock__tv_pipe__carryover__strength': 0.19587267258497543, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.005147718951656777, 'adstock__radio_pipe__carryover__strength': 0.6695044145598306, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.004101220422337331, 'adstock__Social_Media_pipe__carryover__strength': 0.9837079696387497, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.002842098611943297, 'adstock__Macro_pipe__carryover__strength': 0.1263503045229004, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.0027504999688742356, 'adstock__Micro_pipe__carryover__strength': 0.8834719864817824, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.003802400297493112, 'adstock__Nano_pipe__carryover__strength': 0.7676471260996985, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.00569701366298323}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:48,820] Trial 15 finished with value: 0.856036374154937 and parameters: {'adstock__tv_pipe__carryover__strength': 0.2198179394419276, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.004948923791978037, 'adstock__radio_pipe__carryover__strength': 0.6018053633692158, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.0036879564062379136, 'adstock__Social_Media_pipe__carryover__strength': 0.001279064271619057, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.002938691142936063, 'adstock__Macro_pipe__carryover__strength': 0.17706969917661655, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 8.719272638530069e-05, 'adstock__Micro_pipe__carryover__strength': 0.845175573706066, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 9.835375091560034e-05, 'adstock__Nano_pipe__carryover__strength': 0.8846280544880489, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.006196581426146183}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:49,103] Trial 16 finished with value: 0.8521871466519017 and parameters: {'adstock__tv_pipe__carryover__strength': 0.262008423821558, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.008063667909705469, 'adstock__radio_pipe__carryover__strength': 0.8140625098179394, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.0037331218740566073, 'adstock__Social_Media_pipe__carryover__strength': 0.8168840814002514, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.0032732767803050696, 'adstock__Macro_pipe__carryover__strength': 0.4616105902030977, 'adstock__Macro_pipe__carryover__length': 3, 'adstock__Macro_pipe__saturation__a': 7.290425327680093e-05, 'adstock__Micro_pipe__carryover__strength': 0.8172256353425854, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.000131256807982406, 'adstock__Nano_pipe__carryover__strength': 0.9125803830587498, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.00651818973059051}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:49,391] Trial 17 finished with value: 0.8577733999623476 and parameters: {'adstock__tv_pipe__carryover__strength': 0.23568255850372405, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.004520007859139089, 'adstock__radio_pipe__carryover__strength': 0.5652083116758997, 'adstock__radio_pipe__carryover__length': 3, 'adstock__radio_pipe__saturation__a': 0.002994669599929098, 'adstock__Social_Media_pipe__carryover__strength': 0.3302479676066483, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.0030085319515862487, 'adstock__Macro_pipe__carryover__strength': 0.16402636368469675, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.0015300075484961922, 'adstock__Micro_pipe__carryover__strength': 0.8257108190740011, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.0003940979445322115, 'adstock__Nano_pipe__carryover__strength': 0.7840433197882478, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.006210913035003378}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:49,662] Trial 18 finished with value: 0.6610154122060434 and parameters: {'adstock__tv_pipe__carryover__strength': 0.6074003124510101, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.003429939849020208, 'adstock__radio_pipe__carryover__strength': 0.3493739124611547, 'adstock__radio_pipe__carryover__length': 3, 'adstock__radio_pipe__saturation__a': 0.0029929908145775886, 'adstock__Social_Media_pipe__carryover__strength': 0.40043216710060625, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.003963224029490502, 'adstock__Macro_pipe__carryover__strength': 0.4003920665572233, 'adstock__Macro_pipe__carryover__length': 3, 'adstock__Macro_pipe__saturation__a': 0.0016266093555748545, 'adstock__Micro_pipe__carryover__strength': 0.7889705184255628, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.0063273899688549955, 'adstock__Nano_pipe__carryover__strength': 0.7725166171134326, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.007674383468090385}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:50,033] Trial 19 finished with value: 0.8501393618768185 and parameters: {'adstock__tv_pipe__carryover__strength': 0.2962992693162854, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.004837483373009493, 'adstock__radio_pipe__carryover__strength': 0.5780707101292645, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 3.4823325514319724e-05, 'adstock__Social_Media_pipe__carryover__strength': 0.39074499936004853, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.0014570134805842062, 'adstock__Macro_pipe__carryover__strength': 0.16076592405755277, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.0038746226240769796, 'adstock__Micro_pipe__carryover__strength': 0.4233307030807132, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.002437475686050563, 'adstock__Nano_pipe__carryover__strength': 0.7581348592630911, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.0032895967043541315}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:50,434] Trial 20 finished with value: 0.8306092502839579 and parameters: {'adstock__tv_pipe__carryover__strength': 0.15194271105146767, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.00307708636899772, 'adstock__radio_pipe__carryover__strength': 0.8323273609907056, 'adstock__radio_pipe__carryover__length': 3, 'adstock__radio_pipe__saturation__a': 0.004913696105586461, 'adstock__Social_Media_pipe__carryover__strength': 0.8301762319326599, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.003956882703558094, 'adstock__Macro_pipe__carryover__strength': 0.6402164585188541, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0067754412383032115, 'adstock__Micro_pipe__carryover__strength': 0.6591449369929543, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.0012296159446704416, 'adstock__Nano_pipe__carryover__strength': 0.9940585940082813, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.005733479730885017}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:50,730] Trial 21 finished with value: 0.8561161823261335 and parameters: {'adstock__tv_pipe__carryover__strength': 0.22406706887208933, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0049694653453447295, 'adstock__radio_pipe__carryover__strength': 0.568695562398288, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.0034934687392933874, 'adstock__Social_Media_pipe__carryover__strength': 0.1848488710107314, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.002573723042365513, 'adstock__Macro_pipe__carryover__strength': 0.17207200769062372, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 4.0327161231300604e-05, 'adstock__Micro_pipe__carryover__strength': 0.8756883272018674, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.0003080281540760988, 'adstock__Nano_pipe__carryover__strength': 0.8418799420757801, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.007106698212231184}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:51,020] Trial 22 finished with value: 0.855418696948612 and parameters: {'adstock__tv_pipe__carryover__strength': 0.31324462347841503, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.00535774751188613, 'adstock__radio_pipe__carryover__strength': 0.5508387007269505, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.0023611698639070962, 'adstock__Social_Media_pipe__carryover__strength': 0.39132325158691017, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.002027669618264564, 'adstock__Macro_pipe__carryover__strength': 0.9593383388047045, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.0017336502408689316, 'adstock__Micro_pipe__carryover__strength': 0.8843636415698959, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.0006990217080458347, 'adstock__Nano_pipe__carryover__strength': 0.716608134061908, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.007508620940456292}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:51,294] Trial 23 finished with value: 0.8239152462265231 and parameters: {'adstock__tv_pipe__carryover__strength': 0.16494658550321162, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.004614200193114921, 'adstock__radio_pipe__carryover__strength': 0.9953156138712096, 'adstock__radio_pipe__carryover__length': 3, 'adstock__radio_pipe__saturation__a': 0.0037618160124426696, 'adstock__Social_Media_pipe__carryover__strength': 0.19677663526985148, 'adstock__Social_Media_pipe__carryover__length': 0, 'adstock__Social_Media_pipe__saturation__a': 0.003942923166991109, 'adstock__Macro_pipe__carryover__strength': 0.11486989915362789, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0016915584255807912, 'adstock__Micro_pipe__carryover__strength': 0.7571363294964891, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.0029933224687762306, 'adstock__Nano_pipe__carryover__strength': 0.8344346344011695, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.0074052000271628456}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:51,585] Trial 24 finished with value: 0.8526561069276063 and parameters: {'adstock__tv_pipe__carryover__strength': 0.24508336187371024, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.007399918825987416, 'adstock__radio_pipe__carryover__strength': 0.753202026930495, 'adstock__radio_pipe__carryover__length': 2, 'adstock__radio_pipe__saturation__a': 0.004980239244905169, 'adstock__Social_Media_pipe__carryover__strength': 0.31956224182343207, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.002793896601648654, 'adstock__Macro_pipe__carryover__strength': 0.25489515244945926, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.0009220828279848394, 'adstock__Micro_pipe__carryover__strength': 0.8855578674717368, 'adstock__Micro_pipe__carryover__length': 2, 'adstock__Micro_pipe__saturation__a': 0.00056963265590016, 'adstock__Nano_pipe__carryover__strength': 0.7041964508050828, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.00533090930106281}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:51,868] Trial 25 finished with value: 0.8376560321625748 and parameters: {'adstock__tv_pipe__carryover__strength': 0.12221846248838465, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.004239458668248417, 'adstock__radio_pipe__carryover__strength': 0.399504121009464, 'adstock__radio_pipe__carryover__length': 1, 'adstock__radio_pipe__saturation__a': 0.0033394866773118997, 'adstock__Social_Media_pipe__carryover__strength': 0.1935187162201179, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.006195935878172897, 'adstock__Macro_pipe__carryover__strength': 0.38888786755012766, 'adstock__Macro_pipe__carryover__length': 3, 'adstock__Macro_pipe__saturation__a': 0.0035872564950846803, 'adstock__Micro_pipe__carryover__strength': 0.7457112777560099, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.0017746381283668127, 'adstock__Nano_pipe__carryover__strength': 0.8463262792537003, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.006941866001228054}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:52,161] Trial 26 finished with value: 0.6318692363606682 and parameters: {'adstock__tv_pipe__carryover__strength': 0.5783541175583284, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.0031819010860215137, 'adstock__radio_pipe__carryover__strength': 0.5160281754800542, 'adstock__radio_pipe__carryover__length': 3, 'adstock__radio_pipe__saturation__a': 0.002190221736898681, 'adstock__Social_Media_pipe__carryover__strength': 0.09955344451726938, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.0014360997574344584, 'adstock__Macro_pipe__carryover__strength': 0.1026063703076168, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0019564679832015834, 'adstock__Micro_pipe__carryover__strength': 0.6176648494280742, 'adstock__Micro_pipe__carryover__length': 1, 'adstock__Micro_pipe__saturation__a': 0.002905492871085421, 'adstock__Nano_pipe__carryover__strength': 0.9935030774149088, 'adstock__Nano_pipe__carryover__length': 4, 'adstock__Nano_pipe__saturation__a': 0.008375958055498107}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:52,456] Trial 27 finished with value: 0.8579143097779776 and parameters: {'adstock__tv_pipe__carryover__strength': 0.34058479149930676, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.00575309246951676, 'adstock__radio_pipe__carryover__strength': 0.6085503062953176, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.0071896176751787486, 'adstock__Social_Media_pipe__carryover__strength': 0.7254749027585419, 'adstock__Social_Media_pipe__carryover__length': 2, 'adstock__Social_Media_pipe__saturation__a': 0.004372888907983432, 'adstock__Macro_pipe__carryover__strength': 0.22706136553533735, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.000531770804813724, 'adstock__Micro_pipe__carryover__strength': 0.9185895465886703, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.004886409612669783, 'adstock__Nano_pipe__carryover__strength': 0.6886374825942909, 'adstock__Nano_pipe__carryover__length': 5, 'adstock__Nano_pipe__saturation__a': 0.0035213722858301604}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:52,746] Trial 28 finished with value: 0.7479215199897716 and parameters: {'adstock__tv_pipe__carryover__strength': 0.3283687634005111, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.005680953215016783, 'adstock__radio_pipe__carryover__strength': 0.7492716459339263, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.0070057597866477195, 'adstock__Social_Media_pipe__carryover__strength': 0.6894408767695901, 'adstock__Social_Media_pipe__carryover__length': 4, 'adstock__Social_Media_pipe__saturation__a': 0.004345456238972076, 'adstock__Macro_pipe__carryover__strength': 0.5626070488863418, 'adstock__Macro_pipe__carryover__length': 2, 'adstock__Macro_pipe__saturation__a': 0.0010088343603799127, 'adstock__Micro_pipe__carryover__strength': 0.9234785018350755, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.005075007843727265, 'adstock__Nano_pipe__carryover__strength': 0.49722327648477077, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.0034142825264543075}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:53,035] Trial 29 finished with value: 0.6027133059344966 and parameters: {'adstock__tv_pipe__carryover__strength': 0.48988261608074346, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.008144178185672736, 'adstock__radio_pipe__carryover__strength': 0.6189369172494508, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.007364024988565048, 'adstock__Social_Media_pipe__carryover__strength': 0.9323928779277155, 'adstock__Social_Media_pipe__carryover__length': 3, 'adstock__Social_Media_pipe__saturation__a': 0.006113187060999288, 'adstock__Macro_pipe__carryover__strength': 0.2512496501872196, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.004912598634182278, 'adstock__Micro_pipe__carryover__strength': 0.45851862763110923, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.004579920894337362, 'adstock__Nano_pipe__carryover__strength': 0.6886956362179616, 'adstock__Nano_pipe__carryover__length': 6, 'adstock__Nano_pipe__saturation__a': 0.003690046980301646}. Best is trial 14 with value: 0.8585790137417068.
# [I 2024-03-11 17:20:53,320] Trial 30 finished with value: 0.8614026194228908 and parameters: {'adstock__tv_pipe__carryover__strength': 0.3823886857882406, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.00259218261941965, 'adstock__radio_pipe__carryover__strength': 0.40625132604951397, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.004369389941620761, 'adstock__Social_Media_pipe__carryover__strength': 0.7249317923696248, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.003324177904560787, 'adstock__Macro_pipe__carryover__strength': 0.41725112935015396, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.003390880555872133, 'adstock__Micro_pipe__carryover__strength': 0.804963544818936, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.006215570210373001, 'adstock__Nano_pipe__carryover__strength': 0.37432914403631135, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.005804683134783808}. Best is trial 30 with value: 0.8614026194228908.
# [I 2024-03-11 17:20:53,602] Trial 31 finished with value: 0.8611069606014745 and parameters: {'adstock__tv_pipe__carryover__strength': 0.35215571850714233, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.002701992948426132, 'adstock__radio_pipe__carryover__strength': 0.42225772433812603, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.00448548854417718, 'adstock__Social_Media_pipe__carryover__strength': 0.8931309051857556, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.003495373735028103, 'adstock__Macro_pipe__carryover__strength': 0.38480324331711513, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.0031761066799600446, 'adstock__Micro_pipe__carryover__strength': 0.7888552956936706, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.006252858858101141, 'adstock__Nano_pipe__carryover__strength': 0.37082014840659144, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.005601578513667479}. Best is trial 30 with value: 0.8614026194228908.
# [I 2024-03-11 17:20:53,883] Trial 32 finished with value: 0.8426920730923306 and parameters: {'adstock__tv_pipe__carryover__strength': 0.38975013027742855, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.000558948319742905, 'adstock__radio_pipe__carryover__strength': 0.3579791823820144, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.004435733551331927, 'adstock__Social_Media_pipe__carryover__strength': 0.887231891595748, 'adstock__Social_Media_pipe__carryover__length': 0, 'adstock__Social_Media_pipe__saturation__a': 0.00451095241918009, 'adstock__Macro_pipe__carryover__strength': 0.37738641472267054, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.0034106322747502514, 'adstock__Micro_pipe__carryover__strength': 0.7500335875635222, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.006379731510576099, 'adstock__Nano_pipe__carryover__strength': 0.35360553665569344, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.00571306970258879}. Best is trial 30 with value: 0.8614026194228908.
# [I 2024-03-11 17:20:54,225] Trial 33 finished with value: 0.6945963511264306 and parameters: {'adstock__tv_pipe__carryover__strength': 0.4725910485943715, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.0010815790914880017, 'adstock__radio_pipe__carryover__strength': 0.4316664756939905, 'adstock__radio_pipe__carryover__length': 5, 'adstock__radio_pipe__saturation__a': 0.0052592901940972814, 'adstock__Social_Media_pipe__carryover__strength': 0.7208162295774196, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.0033737977659632637, 'adstock__Macro_pipe__carryover__strength': 0.44590535605239245, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.004351533423430111, 'adstock__Micro_pipe__carryover__strength': 0.9235970241461322, 'adstock__Micro_pipe__carryover__length': 4, 'adstock__Micro_pipe__saturation__a': 0.007211291808632474, 'adstock__Nano_pipe__carryover__strength': 0.34720071744894915, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.0052693971238765205}. Best is trial 30 with value: 0.8614026194228908.
# [I 2024-03-11 17:20:54,739] Trial 34 finished with value: 0.8612677581319641 and parameters: {'adstock__tv_pipe__carryover__strength': 0.36146075087301077, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.002701121866968156, 'adstock__radio_pipe__carryover__strength': 0.28046102977319554, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.004414650528697764, 'adstock__Social_Media_pipe__carryover__strength': 0.8727918442298785, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.0035763936560618418, 'adstock__Macro_pipe__carryover__strength': 0.5592914309342583, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.005925589162744546, 'adstock__Micro_pipe__carryover__strength': 0.34152759086857687, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.005795395824292482, 'adstock__Nano_pipe__carryover__strength': 0.3365454595650017, 'adstock__Nano_pipe__carryover__length': 3, 'adstock__Nano_pipe__saturation__a': 0.0028037377965600043}. Best is trial 30 with value: 0.8614026194228908.
# [I 2024-03-11 17:20:55,561] Trial 35 finished with value: 0.6787930688681925 and parameters: {'adstock__tv_pipe__carryover__strength': 0.6428396206588947, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.002685370292616284, 'adstock__radio_pipe__carryover__strength': 0.27585552609769814, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.004310481398165763, 'adstock__Social_Media_pipe__carryover__strength': 0.8891484643320005, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.003518134083334837, 'adstock__Macro_pipe__carryover__strength': 0.5389288708726293, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.005917556686608073, 'adstock__Micro_pipe__carryover__strength': 0.3178967420341039, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.005803324692247021, 'adstock__Nano_pipe__carryover__strength': 0.2738119341667429, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.0025420744565168353}. Best is trial 30 with value: 0.8614026194228908.
# [I 2024-03-11 17:20:56,022] Trial 36 finished with value: 0.6463147984292856 and parameters: {'adstock__tv_pipe__carryover__strength': 0.9694583909929634, 'adstock__tv_pipe__carryover__length': 2, 'adstock__tv_pipe__saturation__a': 0.002540148513188224, 'adstock__radio_pipe__carryover__strength': 0.282572974439152, 'adstock__radio_pipe__carryover__length': 6, 'adstock__radio_pipe__saturation__a': 0.005117831041779453, 'adstock__Social_Media_pipe__carryover__strength': 0.8403532634293042, 'adstock__Social_Media_pipe__carryover__length': 0, 'adstock__Social_Media_pipe__saturation__a': 0.0019691709562237774, 'adstock__Macro_pipe__carryover__strength': 0.5946607017574105, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.007242660324005059, 'adstock__Micro_pipe__carryover__strength': 0.34161477976631843, 'adstock__Micro_pipe__carryover__length': 6, 'adstock__Micro_pipe__saturation__a': 0.007872686989037737, 'adstock__Nano_pipe__carryover__strength': 0.15481371391058596, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.005042906340116095}. Best is trial 30 with value: 0.8614026194228908.
# [I 2024-03-11 17:20:56,724] Trial 37 finished with value: 0.8643769798155532 and parameters: {'adstock__tv_pipe__carryover__strength': 0.455916191557941, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0011636766136973726, 'adstock__radio_pipe__carryover__strength': 0.08309702492699211, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.005643248351208391, 'adstock__Social_Media_pipe__carryover__strength': 0.9094743364722511, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.00993014334531342, 'adstock__Macro_pipe__carryover__strength': 0.7396125908570912, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.005592102071218838, 'adstock__Micro_pipe__carryover__strength': 0.5454491700763741, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.008672882588329954, 'adstock__Nano_pipe__carryover__strength': 0.3324886532006402, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.0062897549937930945}. Best is trial 37 with value: 0.8643769798155532.
# [I 2024-03-11 17:20:57,322] Trial 38 finished with value: 0.7489670014503286 and parameters: {'adstock__tv_pipe__carryover__strength': 0.4478325711795175, 'adstock__tv_pipe__carryover__length': 4, 'adstock__tv_pipe__saturation__a': 0.001262249815768715, 'adstock__radio_pipe__carryover__strength': 0.12654011400426984, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.005573149990685688, 'adstock__Social_Media_pipe__carryover__strength': 0.771103308994981, 'adstock__Social_Media_pipe__carryover__length': 1, 'adstock__Social_Media_pipe__saturation__a': 0.009689062297129092, 'adstock__Macro_pipe__carryover__strength': 0.7414035071130237, 'adstock__Macro_pipe__carryover__length': 6, 'adstock__Macro_pipe__saturation__a': 0.005848265168677305, 'adstock__Micro_pipe__carryover__strength': 0.5320795449830866, 'adstock__Micro_pipe__carryover__length': 3, 'adstock__Micro_pipe__saturation__a': 0.009431599610629098, 'adstock__Nano_pipe__carryover__strength': 0.336986244023878, 'adstock__Nano_pipe__carryover__length': 0, 'adstock__Nano_pipe__saturation__a': 0.009510716266076163}. Best is trial 37 with value: 0.8643769798155532.
# [I 2024-03-11 17:20:57,952] Trial 39 finished with value: 0.7635440507902026 and parameters: {'adstock__tv_pipe__carryover__strength': 0.5273127217605476, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.003868917403122259, 'adstock__radio_pipe__carryover__strength': 0.02677289526682214, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.009582884472797497, 'adstock__Social_Media_pipe__carryover__strength': 0.8979067124520547, 'adstock__Social_Media_pipe__carryover__length': 0, 'adstock__Social_Media_pipe__saturation__a': 0.005775061329014253, 'adstock__Macro_pipe__carryover__strength': 0.9224511511991265, 'adstock__Macro_pipe__carryover__length': 1, 'adstock__Macro_pipe__saturation__a': 0.0054197597016696795, 'adstock__Micro_pipe__carryover__strength': 0.6116947519898782, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.008929093774021945, 'adstock__Nano_pipe__carryover__strength': 0.030355217821974978, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.0029369252753268745}. Best is trial 37 with value: 0.8643769798155532.
# ...
# [I 2024-03-11 17:21:32,642] Trial 88 finished with value: 0.8664193067842871 and parameters: {'adstock__tv_pipe__carryover__strength': 0.6910747466277769, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.001356865472447984, 'adstock__radio_pipe__carryover__strength': 0.25897522029403613, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.006855519628068696, 'adstock__Social_Media_pipe__carryover__strength': 0.39338503524312496, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.008571030208084035, 'adstock__Macro_pipe__carryover__strength': 0.7711527214034677, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.005761755110997815, 'adstock__Micro_pipe__carryover__strength': 0.15082038903368053, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.007801955814456809, 'adstock__Nano_pipe__carryover__strength': 0.5477408866174373, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.0024469706396922693}. Best is trial 86 with value: 0.8674695075381347.
# [I 2024-03-11 17:21:33,275] Trial 89 finished with value: 0.8687383233218773 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7308988985715845, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.001280728613970493, 'adstock__radio_pipe__carryover__strength': 0.3484830516188324, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.0068091280178334485, 'adstock__Social_Media_pipe__carryover__strength': 0.6097778701055326, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.009999966295278466, 'adstock__Macro_pipe__carryover__strength': 0.8197398213202243, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.005173274473890295, 'adstock__Micro_pipe__carryover__strength': 0.08129526075111157, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.006168919713088185, 'adstock__Nano_pipe__carryover__strength': 0.5476934665851415, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.001509412366168644}. Best is trial 89 with value: 0.8687383233218773.
# [I 2024-03-11 17:21:33,667] Trial 90 finished with value: 0.5632769731145404 and parameters: {'adstock__tv_pipe__carryover__strength': 0.6975178824499506, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.0013760206630372626, 'adstock__radio_pipe__carryover__strength': 0.6330435285174072, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.006901857523611109, 'adstock__Social_Media_pipe__carryover__strength': 0.6302598597875124, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.009978309235474925, 'adstock__Macro_pipe__carryover__strength': 0.774271653266506, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.005107020083345418, 'adstock__Micro_pipe__carryover__strength': 0.09191507649947414, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.006122985908197645, 'adstock__Nano_pipe__carryover__strength': 0.46616093571823725, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.0007198157257355107}. Best is trial 89 with value: 0.8687383233218773.
# [I 2024-03-11 17:21:34,106] Trial 91 finished with value: 0.8675570007228238 and parameters: {'adstock__tv_pipe__carryover__strength': 0.7278455960441401, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.001372714477741055, 'adstock__radio_pipe__carryover__strength': 0.34830807564690114, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.007350685443164253, 'adstock__Social_Media_pipe__carryover__strength': 0.5150830770911852, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.008590582732902943, 'adstock__Macro_pipe__carryover__strength': 0.8106566752534239, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.005744461721850923, 'adstock__Micro_pipe__carryover__strength': 0.14864639340115549, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.008189044704347986, 'adstock__Nano_pipe__carryover__strength': 0.5514769029033983, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.0022548236579434714}. Best is trial 89 with value: 0.8687383233218773.
# [I 2024-03-11 17:21:34,603] Trial 92 finished with value: 0.8564874386596699 and parameters: {'adstock__tv_pipe__carryover__strength': 0.732083949821373, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0007247592510600183, 'adstock__radio_pipe__carryover__strength': 0.2675403904263396, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.0073398435326849365, 'adstock__Social_Media_pipe__carryover__strength': 0.6068106218987455, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.008588502858697316, 'adstock__Macro_pipe__carryover__strength': 0.8230195423611879, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.005778752438628777, 'adstock__Micro_pipe__carryover__strength': 0.15086449852539174, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.007821824660747522, 'adstock__Nano_pipe__carryover__strength': 0.6232160791325186, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.0015330441923319487}. Best is trial 89 with value: 0.8687383233218773.
# [I 2024-03-11 17:21:35,178] Trial 93 finished with value: 0.8679786834174953 and parameters: {'adstock__tv_pipe__carryover__strength': 0.9372606467231615, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0012250588830686844, 'adstock__radio_pipe__carryover__strength': 0.41663654385454607, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.006554903826646928, 'adstock__Social_Media_pipe__carryover__strength': 0.5491699019062362, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.007714952502828996, 'adstock__Macro_pipe__carryover__strength': 0.8379788785581678, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.0052816515241919555, 'adstock__Micro_pipe__carryover__strength': 0.0808817065022841, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.0073183457108535145, 'adstock__Nano_pipe__carryover__strength': 0.5829044489753041, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.0011808163435763704}. Best is trial 89 with value: 0.8687383233218773.
# [I 2024-03-11 17:21:35,792] Trial 94 finished with value: 0.8680077549865188 and parameters: {'adstock__tv_pipe__carryover__strength': 0.9381691780781772, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0013024194311430607, 'adstock__radio_pipe__carryover__strength': 0.5196786079678696, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.006542702867964727, 'adstock__Social_Media_pipe__carryover__strength': 0.5109679827598659, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.007837174302785124, 'adstock__Macro_pipe__carryover__strength': 0.835548301772693, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.005321658597125141, 'adstock__Micro_pipe__carryover__strength': 0.07008755248458615, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.00604508195321176, 'adstock__Nano_pipe__carryover__strength': 0.58389091322621, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.0011614584644010356}. Best is trial 89 with value: 0.8687383233218773.
# [I 2024-03-11 17:21:36,459] Trial 95 finished with value: 0.47185220515709914 and parameters: {'adstock__tv_pipe__carryover__strength': 0.9973427070092964, 'adstock__tv_pipe__carryover__length': 3, 'adstock__tv_pipe__saturation__a': 0.0012576149412568995, 'adstock__radio_pipe__carryover__strength': 0.5844392711727708, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.006616277735610908, 'adstock__Social_Media_pipe__carryover__strength': 0.5114998272196045, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.007531037594426238, 'adstock__Macro_pipe__carryover__strength': 0.8335473901626987, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.004348361731456222, 'adstock__Micro_pipe__carryover__strength': 0.08359021882451709, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.006048247187524479, 'adstock__Nano_pipe__carryover__strength': 0.5429269588457522, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.001048715644629169}. Best is trial 89 with value: 0.8687383233218773.
# [I 2024-03-11 17:21:37,093] Trial 96 finished with value: 0.7591442018467925 and parameters: {'adstock__tv_pipe__carryover__strength': 0.9683579889625179, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0003168504304594823, 'adstock__radio_pipe__carryover__strength': 0.501769582670192, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.006860499146408844, 'adstock__Social_Media_pipe__carryover__strength': 0.6651712023816473, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.007948240896994287, 'adstock__Macro_pipe__carryover__strength': 0.8025803704324295, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.005365754163102646, 'adstock__Micro_pipe__carryover__strength': 0.12784656052997792, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.006432659003408611, 'adstock__Nano_pipe__carryover__strength': 0.49046779398796847, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.00020270757195486042}. Best is trial 89 with value: 0.8687383233218773.
# [I 2024-03-11 17:21:37,661] Trial 97 finished with value: 0.8658630703398413 and parameters: {'adstock__tv_pipe__carryover__strength': 0.8721081099253403, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.001968282766213531, 'adstock__radio_pipe__carryover__strength': 0.5460645792934589, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.006348349407319851, 'adstock__Social_Media_pipe__carryover__strength': 0.5091958788195661, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.007048127675752407, 'adstock__Macro_pipe__carryover__strength': 0.7607042284517943, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.00571727113743811, 'adstock__Micro_pipe__carryover__strength': 0.03366511040467498, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.005480166104993406, 'adstock__Nano_pipe__carryover__strength': 0.5591220219555626, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.001411540986434076}. Best is trial 89 with value: 0.8687383233218773.
# [I 2024-03-11 17:21:38,634] Trial 98 finished with value: 0.8642325502661213 and parameters: {'adstock__tv_pipe__carryover__strength': 0.8868408505418286, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.0027821427658725954, 'adstock__radio_pipe__carryover__strength': 0.556023354546893, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.006330720961228965, 'adstock__Social_Media_pipe__carryover__strength': 0.5492777166276308, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.007434184663961141, 'adstock__Macro_pipe__carryover__strength': 0.762567434759099, 'adstock__Macro_pipe__carryover__length': 5, 'adstock__Macro_pipe__saturation__a': 0.005661303026623634, 'adstock__Micro_pipe__carryover__strength': 0.05738518951242212, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.00546195798047433, 'adstock__Nano_pipe__carryover__strength': 0.5211637958684197, 'adstock__Nano_pipe__carryover__length': 1, 'adstock__Nano_pipe__saturation__a': 0.0012581224420637302}. Best is trial 89 with value: 0.8687383233218773.
# [I 2024-03-11 17:21:39,344] Trial 99 finished with value: 0.544204492251726 and parameters: {'adstock__tv_pipe__carryover__strength': 0.8750009559711839, 'adstock__tv_pipe__carryover__length': 1, 'adstock__tv_pipe__saturation__a': 0.0020247876507018987, 'adstock__radio_pipe__carryover__strength': 0.5139625596672083, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.007363395466079821, 'adstock__Social_Media_pipe__carryover__strength': 0.5146022156795286, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.00780353006852115, 'adstock__Macro_pipe__carryover__strength': 0.8384898374424009, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.004970719057778585, 'adstock__Micro_pipe__carryover__strength': 0.00045253934862799633, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.0044996985337919125, 'adstock__Nano_pipe__carryover__strength': 0.44082897426253914, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.002011238690801024}. Best is trial 89 with value: 0.8687383233218773.
# OptunaSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                estimator=Pipeline(steps=[('adstock',
#                                           ColumnTransformer(remainder='passthrough',
#                                                             transformers=[('tv_pipe',
#                                                                            Pipeline(steps=[('carryover',
#                                                                                             ExponentialCarryover()),
#                                                                                            ('saturation',
#                                                                                             ExponentialSaturation())]),
#                                                                            ['TV']),
#                                                                           ('radio_pipe',
#                                                                            Pipeline(steps=[('carryover',
#                                                                                             ExponentialCar...
#                                     'adstock__radio_pipe__carryover__strength': UniformDistribution(high=1.0, low=0.0),
#                                     'adstock__radio_pipe__saturation__a': UniformDistribution(high=0.01, low=0.0),
#                                     'adstock__tv_pipe__carryover__length': IntUniformDistribution(high=6, low=0, step=1),
#                                     'adstock__tv_pipe__carryover__strength': UniformDistribution(high=1.0, low=0.0),
#                                     'adstock__tv_pipe__saturation__a': UniformDistribution(high=0.01, low=0.0)},
#                random_state=0)

# %% [markdown]
# - ## The optimal hyperparameters are the following:

# %%
print(tuned_model.best_params_)
print(tuned_model.best_estimator_.named_steps['regression'].coef_)
print(tuned_model.best_estimator_.named_steps['regression'].intercept_)
# Out:
# {'adstock__tv_pipe__carryover__strength': 0.7308988985715845, 'adstock__tv_pipe__carryover__length': 0, 'adstock__tv_pipe__saturation__a': 0.001280728613970493, 'adstock__radio_pipe__carryover__strength': 0.3484830516188324, 'adstock__radio_pipe__carryover__length': 4, 'adstock__radio_pipe__saturation__a': 0.0068091280178334485, 'adstock__Social_Media_pipe__carryover__strength': 0.6097778701055326, 'adstock__Social_Media_pipe__carryover__length': 6, 'adstock__Social_Media_pipe__saturation__a': 0.009999966295278466, 'adstock__Macro_pipe__carryover__strength': 0.8197398213202243, 'adstock__Macro_pipe__carryover__length': 4, 'adstock__Macro_pipe__saturation__a': 0.005173274473890295, 'adstock__Micro_pipe__carryover__strength': 0.08129526075111157, 'adstock__Micro_pipe__carryover__length': 5, 'adstock__Micro_pipe__saturation__a': 0.006168919713088185, 'adstock__Nano_pipe__carryover__strength': 0.5476934665851415, 'adstock__Nano_pipe__carryover__length': 2, 'adstock__Nano_pipe__saturation__a': 0.001509412366168644}
# [2804.12460007  177.36046015  333.86085015  101.01288026  -44.43905482
#    -6.19207237]
# 57.52780685402584

# %% [markdown]
# - ## Printing best Parameter value for each X variable in a DataFrame

# %%
# Getting adstock parameters of the Tuned Model for each channel throgh a DataFrame
value = pd.DataFrame.from_dict(tuned_model.best_params_, orient = 'index', columns=["value"])
value.style.background_gradient()
# Out:
# <style type="text/css">
# #T_72510_row0_col0 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_72510_row1_col0, #T_72510_row2_col0, #T_72510_row5_col0, #T_72510_row8_col0, #T_72510_row11_col0, #T_72510_row14_col0, #T_72510_row17_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_72510_row3_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_72510_row4_col0, #T_72510_row10_col0 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_72510_row6_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_72510_row7_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_72510_row9_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_72510_row12_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_72510_row13_col0 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_72510_row15_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_72510_row16_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# </style>
# <table id="T_72510" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72510_level0_col0" class="col_heading level0 col0" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72510_level0_row0" class="row_heading level0 row0" >adstock__tv_pipe__carryover__strength</th>
#       <td id="T_72510_row0_col0" class="data row0 col0" >0.730899</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row1" class="row_heading level0 row1" >adstock__tv_pipe__carryover__length</th>
#       <td id="T_72510_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row2" class="row_heading level0 row2" >adstock__tv_pipe__saturation__a</th>
#       <td id="T_72510_row2_col0" class="data row2 col0" >0.001281</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row3" class="row_heading level0 row3" >adstock__radio_pipe__carryover__strength</th>
#       <td id="T_72510_row3_col0" class="data row3 col0" >0.348483</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row4" class="row_heading level0 row4" >adstock__radio_pipe__carryover__length</th>
#       <td id="T_72510_row4_col0" class="data row4 col0" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row5" class="row_heading level0 row5" >adstock__radio_pipe__saturation__a</th>
#       <td id="T_72510_row5_col0" class="data row5 col0" >0.006809</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row6" class="row_heading level0 row6" >adstock__Social_Media_pipe__carryover__strength</th>
#       <td id="T_72510_row6_col0" class="data row6 col0" >0.609778</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row7" class="row_heading level0 row7" >adstock__Social_Media_pipe__carryover__length</th>
#       <td id="T_72510_row7_col0" class="data row7 col0" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row8" class="row_heading level0 row8" >adstock__Social_Media_pipe__saturation__a</th>
#       <td id="T_72510_row8_col0" class="data row8 col0" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row9" class="row_heading level0 row9" >adstock__Macro_pipe__carryover__strength</th>
#       <td id="T_72510_row9_col0" class="data row9 col0" >0.819740</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row10" class="row_heading level0 row10" >adstock__Macro_pipe__carryover__length</th>
#       <td id="T_72510_row10_col0" class="data row10 col0" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row11" class="row_heading level0 row11" >adstock__Macro_pipe__saturation__a</th>
#       <td id="T_72510_row11_col0" class="data row11 col0" >0.005173</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row12" class="row_heading level0 row12" >adstock__Micro_pipe__carryover__strength</th>
#       <td id="T_72510_row12_col0" class="data row12 col0" >0.081295</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row13" class="row_heading level0 row13" >adstock__Micro_pipe__carryover__length</th>
#       <td id="T_72510_row13_col0" class="data row13 col0" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row14" class="row_heading level0 row14" >adstock__Micro_pipe__saturation__a</th>
#       <td id="T_72510_row14_col0" class="data row14 col0" >0.006169</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row15" class="row_heading level0 row15" >adstock__Nano_pipe__carryover__strength</th>
#       <td id="T_72510_row15_col0" class="data row15 col0" >0.547693</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row16" class="row_heading level0 row16" >adstock__Nano_pipe__carryover__length</th>
#       <td id="T_72510_row16_col0" class="data row16 col0" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_72510_level0_row17" class="row_heading level0 row17" >adstock__Nano_pipe__saturation__a</th>
#       <td id="T_72510_row17_col0" class="data row17 col0" >0.001509</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see from the above results, TV has the most carryover strength while Social Media & Radio have most carryover length. It means TV ads have high impact on Sales after initial spending, but they don't last long, quickly wear off in the same week. While Social Media and Radio have relatively less impact on Sales but they still have an effect on sales respectably 4 & 6 weeks later. Interestingly Macro influencers have both high carryover length and strength.

# %%
# applying get_value() function for tv saturation
tv_sat_a = value._get_value('adstock__tv_pipe__saturation__a', 'value')
tv_sat_a
# Out:
# 0.001280728613970493

# %%
# applying get_value() function for radio saturation
radio_sat_a = value._get_value('adstock__radio_pipe__saturation__a', 'value')
radio_sat_a
# Out:
# 0.0068091280178334485

# %%
# applying get_value() function for social media saturation
Social_Media_sat_a = value._get_value('adstock__Social_Media_pipe__saturation__a', 'value')
Social_Media_sat_a
# Out:
# 0.009999966295278466

# %%
# applying get_value() function for macro saturation
Macro_sat_a = value._get_value('adstock__Macro_pipe__saturation__a', 'value')
Macro_sat_a
# Out:
# 0.005173274473890295

# %%
# applying get_value() function for micro saturation
Micro_sat_a = value._get_value('adstock__Micro_pipe__saturation__a', 'value')
Micro_sat_a
# Out:
# 0.006168919713088185

# %%
# applying get_value() function for nano saturation
Nano_sat_a = value._get_value('adstock__Nano_pipe__saturation__a', 'value')
Nano_sat_a
# Out:
# 0.001509412366168644

# %% [markdown]
# - ## Calculating Exponents of all X variables

# %%
y_axis_TV = 1 - np.exp(range(0,1100)*(-tv_sat_a))
y_axis_radio = 1 - np.exp(range(0,1100)*(-radio_sat_a))
y_axis_Social_Media = 1 - np.exp(range(0,1100)*(-Social_Media_sat_a))
y_axis_Macro = 1 - np.exp(range(0,1100)*(-Macro_sat_a))
y_axis_Micro = 1 - np.exp(range(0,1100)*(-Micro_sat_a))
y_axis_Nano = 1 - np.exp(range(0,1100)*(-Nano_sat_a))

# %% [markdown]
# # Saturation Effect

# %% [markdown]
# - ## Without Selecting the Dummy variables

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
plt.figure(figsize=(17,8))

plt.plot(range(0,1100), y_axis_TV, label='TV')
plt.plot(range(0,1100), y_axis_radio, label='Radio')
plt.plot(range(0,1100), y_axis_Social_Media, label='Social Media')

plt.legend()
plt.show()

# %% [markdown]
# We are getting saturation graph of tv radio and social media in same plot it is making sense to compare their saturation graphically.\
# From here it seems like spending more than 300 is useless for Radio and spending more than 230 is useless for Social Media

# %% [markdown]
# - ## With using the Dummy variables

# %%
plt.figure(figsize=(17,8))

plt.plot(range(0,1100),y_axis_TV, label='TV')
plt.plot(range(0,1100),y_axis_radio, label='RADIO')
plt.plot(range(0,1100),y_axis_Social_Media, label='Social Media')
plt.plot(range(0,1100),y_axis_Macro, label='Macro influencer')
plt.plot(range(0,1100),y_axis_Micro, label='Micro influencer')
plt.plot(range(0,1100),y_axis_Nano, label='Nano influencer')

plt.legend()
plt.show()

# %% [markdown]
# In the above chart, we are getting saturation graph of tv, radio, social media and other dummy influencers.

# %% [markdown]
# # Carryover Effects

# %% [markdown]
# > ### For TV

# %%
tv_carry_week = int(value._get_value('adstock__tv_pipe__carryover__length', 'value'))
w = 100
tv_carry_strength = value._get_value('adstock__tv_pipe__carryover__strength', 'value')
val={0:100}
for i in range(1,tv_carry_week+1):
  val[i] = w*tv_carry_strength
  w=w*tv_carry_strength

week_no = list(val.keys())
values = list(val.values())
plt.bar(week_no, values)
val
# Out:
# {0: 100}

# %% [markdown]
# > ### For Radio

# %%
radio_carry_week = int(value._get_value('adstock__radio_pipe__carryover__length', 'value'))
w = 100
val = {0:100}
radio_carry_strength = value._get_value('adstock__radio_pipe__carryover__strength', 'value')
for i in range(1, radio_carry_week + 1):
  val[i] = w * radio_carry_strength
  w = w * radio_carry_strength

week_no = list(val.keys())
values = list(val.values())
plt.bar(week_no, values)
val
# Out:
# {0: 100,
#  1: 34.84830516188324,
#  2: 12.144043726557381,
#  3: 4.231993416823254,
#  4: 1.474777980325377}

# %% [markdown]
# > ###  For Social Media

# %%
Social_Media_carry_week = int(value._get_value('adstock__Social_Media_pipe__carryover__length', 'value'))
#Social_Media_carry_week = 6

w=100
Social_Media_carry_strength = value._get_value('adstock__Social_Media_pipe__carryover__strength', 'value')
val={0:100}

for i in range(1,Social_Media_carry_week+1):
  val[i] = w*Social_Media_carry_strength
  w=w*Social_Media_carry_strength

week_no = list(val.keys())
values = list(val.values())
plt.bar(week_no, values)
val
# Out:
# {0: 100,
#  1: 60.977787010553264,
#  2: 37.182905087043984,
#  3: 22.673312668313855,
#  4: 13.825684307121213,
#  5: 8.43059632954786,
#  6: 5.140791073551216}

# %% [markdown]
# > ### For Macro Influencers

# %%
Macro_carry_week = int(value._get_value('adstock__Macro_pipe__carryover__length', 'value'))

w=100
Macro_carry_strength = value._get_value('adstock__Macro_pipe__carryover__strength', 'value')
val={0:100}

for i in range(1,Macro_carry_week+1):
  val[i] = w*Macro_carry_strength
  w=w*Macro_carry_strength

week_no = list(val.keys())
values = list(val.values())
plt.bar(week_no, values)
val
# Out:
# {0: 100,
#  1: 81.97398213202243,
#  2: 67.19733746581132,
#  3: 55.08433340741898,
#  4: 45.1548216249413}

# %% [markdown]
# - ### For Micro Influencers

# %%
Micro_carry_week = int(value._get_value('adstock__Micro_pipe__carryover__length', 'value'))

w=100
Micro_carry_strength = value._get_value('adstock__Micro_pipe__carryover__strength', 'value')
val={0:100}

for i in range(1,Micro_carry_week+1):
  val[i] = w*Micro_carry_strength
  w=w*Micro_carry_strength

week_no = list(val.keys())
values = list(val.values())
plt.bar(week_no, values)
val
# Out:
# {0: 100,
#  1: 8.129526075111157,
#  2: 0.660891942059122,
#  3: 0.053727382758004844,
#  4: 0.00436778159078678,
#  5: 0.00035507994332691615}

# %% [markdown]
# > ### For Nano Influencers

# %%
Nano_carry_week = int(value._get_value('adstock__Nano_pipe__carryover__length', 'value'))

w=100
Nano_carry_strength = value._get_value('adstock__Nano_pipe__carryover__strength', 'value')
val={0:100}

for i in range(1,Nano_carry_week+1):
  val[i] = w*Nano_carry_strength
  w=w*Nano_carry_strength

week_no = list(val.keys())
values = list(val.values())
plt.bar(week_no, values)
val
# Out:
# {0: 100, 1: 54.76934665851415, 2: 29.99681333400495}

# %% [markdown]
# It seems that radio and Social Media advertisings still have an effect on sales respectably 4 & 6 weeks later after the initial spending. This is longer than the effect of TV spendings that quickly wear off in the same week.

# %% [markdown]
# # Channel Contributions

# %%
adstock_data = pd.DataFrame(
    tuned_model.best_estimator_.named_steps['adstock'].transform(X2),
    columns=X2.columns,
    index=X2.index
)
weights = pd.Series(
    tuned_model.best_estimator_.named_steps['regression'].coef_,
    index=X2.columns
)
base = tuned_model.best_estimator_.named_steps['regression'].intercept_
unadj_contributions = adstock_data.mul(weights).assign(Base=base)
adj_contributions = (unadj_contributions
                     .div(unadj_contributions.sum(axis=1), axis=0)
                     .mul(y, axis=0)
                    )
ax = (adj_contributions[['Base', 'Social_Media', 'Radio', 'TV', 'Macro', 'Micro', 'Nano']]
      .plot.area(
          figsize=(16, 10),
          linewidth=1,
          title='Predicted Sales and Breakdown',
          ylabel='Sales',
          xlabel='Date'
      )
     )

handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles[::-1], labels[::-1],
    title='Channels', loc="center left",
    bbox_to_anchor=(1.01, 0.5)
)

# %% [markdown]
# It seems Macro influencers have an higher impact on sales, even greater than TV which additionally still has an effect on sales 4 weeks later after initial spending.

# %% [markdown]
# # Comparing Actual and Predicted values

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(X2, y2 ,test_size=0.35, random_state=101)
y_pred2 = tuned_model.predict(X_test3)
test3 = pd.DataFrame({'Predicted sales':y_pred2, 'Actual sales':y_test3})
fig= plt.figure(figsize=(16,8))
test3 = test3.reset_index()
test3 = test3.drop(['Date'],axis=1)
plt.plot(test3[:50])
plt.legend(['Actual sales','Predicted sales'])

# %% [markdown]
# # Checking For Multicollinearity using VIF values of the Explanatory Variables

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X3 = X2.copy()
X3['Constant'] = 1
vif = [variance_inflation_factor(X3.values, i) for i in range(len(X3.columns))]
pd.Series(vif, index=X3.columns)
# Out:
# TV              3.938138
# Radio           4.592562
# Social_Media    1.588171
# Macro           1.485022
# Micro           1.493019
# Nano            1.489887
# Constant        8.405170
# dtype: float64

# %% [markdown]
# From the above results we can clearly see there is no Multicollinearity issue between the independent variables (all values are less than 5)

# %%
X3.head()
# Out:
#             TV      Radio  Social_Media  Macro  Micro  Nano  Constant
# Date
# 2001-01-01  54  14.119060      4.215642      0      0     1         1
# 2001-01-02  65  26.217056      5.481302      1      0     0         1
# 2001-01-03  67  16.705375      2.657608      1      0     0         1
# 2001-01-04  73  31.327127     10.260554      0      0     1         1
# 2001-01-05  28  17.343639      2.071636      0      1     0         1

# %% [markdown]
# # Using docplex to implement Solver in Python
# Solver adjusts the values in the decision variable cells to satisfy the limits on constraint cells and produce the result you want for the objective cell.
# Ex: - Determining the monthly product mix for a drug manufacturing unit that maximizes the profitability.
#
# - ## Scenario:
# Suppose we are a big multimillion dollar company, we want to spread awareness  of our products to customers by placing advertisements through Tv, Radio and Social Media. But we have a tight budget of, lets say $100000. We want to maximize our revenue, but we don't know how much budget we should allocate to each channel. Thats where Solver comes in.

# %% [markdown]
# - ### Necessary Libraries

# %%
# !pip install docplex
# !pip install cplex
from docplex.mp.model import Model
# Out:
# Collecting docplex
#   Downloading docplex-2.25.236.tar.gz (633 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.5/633.5 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from docplex) (1.16.0)
# Building wheels for collected packages: docplex
#   Building wheel for docplex (setup.py) ... done
#   Created wheel for docplex: filename=docplex-2.25.236-py3-none-any.whl size=671351 sha256=0ba3620ec40909c7300cfe7a65c0b9e0b9eba022b921f88dfcdf1752a98a58c4
#   Stored in directory: /root/.cache/pip/wheels/3b/e5/00/0bf0173d67188fe73a13e3a61412b3f975f60205e3fab93a69
# Successfully built docplex
# Installing collected packages: docplex
# Successfully installed docplex-2.25.236
# Collecting cplex
#   Downloading cplex-22.1.1.0-cp310-cp310-manylinux1_x86_64.whl (44.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 MB 12.7 MB/s eta 0:00:00
# Installing collected packages: cplex
# Successfully installed cplex-22.1.1.0

# %%
m = Model(name = 'Optimization_for_MMM')

# %% [markdown]
# Our Simple Linear Regression equation for the original data was:
# > ### <b>Sales = 85.1463 + 3.4555 * TV + 0.98 * Radio + 2.469 * Social Media</b>
#
# - ## Variables

# %%
TV = m.integer_var(name='TV')
Radio = m.integer_var(name='Radio')
SM = m.integer_var(name='Social_Media')

# %% [markdown]
# - ## Constraints

# %% [markdown]
# > ### TV

# %%
# Adding constraints that Tv budget value should be non negative
TV_non_neg = m.add_constraint(TV >= 0)

# %% [markdown]
# > #### Radio

# %%
# Adding maximum and minimum budget constraint to radio
Radio_Min = m.add_constraint(Radio >= 120)
Radio_Max = m.add_constraint(Radio <= 300)
Radio_non_neg = m.add_constraint(Radio >= 0)

# %% [markdown]
# > ### Social Media Constraints

# %%
# Adding maximum and minimum budget constraint to Social Media
SM_Min = m.add_constraint(SM >= 100)
SM_Max = m.add_constraint(SM <= 230)
SM_non_neg = m.add_constraint(SM >= 0)

# %% [markdown]
# - ### Constraint on total ad Spent

# %%
# Fixing Total budget constraint
Total_budget_max = m.add_constraint(m.sum([TV + Radio + SM]) <= 100000)

# %% [markdown]
# - ### Coefficients from Linear Regression

# %%
TV_coef = 3.4555
Radio_coef = 0.98
SM_coef = 2.469
intercept = 85.1463

# %% [markdown]
# - ### Optimized Budget

# %%
# Maximizing the Sales/Revenue through the intercept and coefficients of linear regression
m.maximize(TV*TV_coef + Radio*Radio_coef + SM*SM_coef + intercept)

# %%
sol = m.solve()

# %%
# Printing the result
sol.display()
# Out:
# solution for: Optimization_for_MMM
# objective: 345239.436
# status: OPTIMAL_SOLUTION(2)
# TV = 99780
# Radio = 120
# Social_Media = 100

# %% [markdown]
# So, based on the results, if we have $100000 budget and we want to maximize our return of investment or objective, we should allocate 99780 dollars on Tv advertisements, 120 dollars on Radio advertisement and 100 dollars on Social Media advertisement.
